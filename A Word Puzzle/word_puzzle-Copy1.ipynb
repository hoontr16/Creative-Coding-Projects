# %% [markdown]
# <h1>What does this program do?</h1>
#
# Turn a selection of words into a puzzle.
#
# <h2>What is the puzzle?</h2>
#
# One aspect of every word changes, and the reader must either figure out what changed, or what the original text said.
#
# <h2>What is changed about the words?</h2>
#
# There are three possible changes for each word: spelling, pronounciation, and definition.
#
# <h3>Definition</h3>
#
# The program looks the word up in an online dictionary, and replaces it with a word offset from the original by some amount. For example, the 10th word after it, or the 6th word before it.
#
# <h3>Spelling & Pronounciation</h3>
#
# Since this puzzle is entirely text-based, changes to pronounciation must actually affect its spelling. Therefore, changes to spelling and pronounciation both change spelling, but in different ways.
#
# A word consists of three aspects: appearance, sound, and meaning. Its meaning is abstract, applied to a word by historical use and present societal use and understanding. As for appearance and sound, a graphical representation of an English word consists of letters, which then represent sounds. Individual sounds are called __phonemes__, and the letters or groups of letters that represent phonemes are called __graphemes__.
#
# Phonemes in English have a plethora of irregular spellings, some only appearing in a single word (and its derivatives). That is what my program will play on. When changing the _spelling_ of a word, it will pick a random phoneme and its associated grapheme in the word, and change the grapheme to another valid representation of that same phoneme, for example changing 'thaw' to 'tho', where the 'aw' sound is spelled like the 'o' in 'bog'. However, when changing a _pronounciation_, it selects a random phoneme in the word and replaces it with another phoneme, and pick a valid grapheme.
#
# <h4>How does the program know what phonemes are?</h4>
# It will look up the word on Wiktionary, which has the IPA representation of the word. Each IPA symbol is a phoneme, and each phoneme is exactly one symbol.
#
# <h4>How will Python recognize IPA symbols?</h4>
# Hopefully I can use Unicode. Otherwise, I don't know
#
# <h4>What about English vowels? How will you represent their complexity?</h4>
#
#
# <h1>IDEA:</h1>
# instead of directly changing the phoneme/grapheme, the program picks an English dialect to start with, and another to change it to. It then changes the spelling of the word to match how someone speaking the first dialect would spell the pronounciation of someone in the second dialect.

# %% [markdown]
# 10/15
#
# Step 1: write code that can understand phonemes and break words down into them
#
# Step 2: use some base text to derive all possible spellings of each phoneme

# %%
with open('cmuDict.txt', 'r', encoding='utf-8') as f:
    rawDict = f.read()

cmu = rawDict.split('\n')[56:]
print(cmu[0])
# Out:
# !EXCLAMATION-POINT  EH2 K S K L AH0 M EY1 SH AH0 N P OY2 N T

# %% [markdown]
# Problem: though I now have a phonetic spelling of most English words, it cannot tell me which grapheme each sound belongs to. Some graphemes consist of multiple letters, and others represent multiple distinct phonemes
#
# Solution?: first, assume that each letter is its own grapheme. if correct, then move on. otherwise, for the graphemes that do not cleanly match, try sticking letters together until it matches.

# %%
testWord = cmu[0].strip('! ')
word, pron = testWord.split(maxsplit=1)
word = word.strip()
pron = pron.strip()
print(word, '\n', pron)
phonemes_old = pron.split()
# Out:
# EXCLAMATION-POINT
#  EH2 K S K L AH0 M EY1 SH AH0 N P OY2 N T

# %% [markdown]
# 10/17
#
# in the ARPAbet, some symbols represent vowel sounds, and others consonants. there is always at least one vowel per word. so, words can be broken up into chunks with exactly one vowel sound each.

# %%
useful_words = {}
for w in cmu:
    try:
        t, p = w.split(maxsplit=1)
        useful_words[t] = p
    except (IndexError, ValueError) as e:
        print(w)
        print(e)

# %%
useful_words = {w.split(maxsplit=1)[0]: w.split(maxsplit=1)[1] for w in cmu}

# %%
useful_words['LIAISON']
# Out:
# 'L IY0 EY1 Z AA2 N'

# %%
testWord2 = cmu[100].strip('! ')
word, pron = testWord2.split(maxsplit=1)
word = word.strip()
pron = pron.strip()
print(word, '\n', pron)
phonemes = pron.split()
# Out:
# AARONSON(1)
#  AA1 R AH0 N S AH0 N

# %%
print(type(phonemes[0]))
# Out:
# <class 'str'>

# %%
vowels = [    # General American English specifically
    'AA',     # balm, bot
    'AE',     # bat
    'AH',     # butt
    'AO',     # stOry      this gave me a heart attack when Wikipedia gave another example as 'cAUGHt' which is not at all the same sound to me
    'AW',     # bout
    'AX',     # commA (schwa)
    'AY',     # bite
    'EH',     # bet
    'ER',     # bIRd, forewORd
    'EY',     # bait
    'IH',     # bit
    'IX',     # rosEs, rabbIt
    'IY',     # beat
    'OW',     # boat
    'OY',     # boy
    'UH',     # book
    'UW'      # boot
]
# source: https://en.wikipedia.org/wiki/ARPABET
consonants = [
    'B',      # buy
    'CH',     # China
    'D',      # die
    'DH',     # thy
    'DX',     # buTTer
    'EL',     # bottLE
    'EM',     # rhythM
    'EN',     # buttON
    'F',      # fight
    'G',      # guy
    'HH',     # High
    'JH',     # jive
    'K',      # kite
    'L',      # lie
    'M',      # my
    'N',      # nigh
    'NG',     # siNG
    'P',      # pie
    'Q',      # uh-oh (glottal stop)
    'R',      # rye
    'S',      # sigh
    'SH',     # shy
    'T',      # tie
    'TH',     # thigh
    'V',      # vie
    'W',      # wise
    'WH',     # why (for fancy people)
    'Y',      # yacht
    'Z',      # zoo
    'ZH'      # pleaSure
]

# %%
class coolWord:
    def __init__(self, spelling, pronounciation):
        symbols = "~!@#$%^&*()-_=+[]{}\\|;:\'\",<.>/?1234567890"
        self.word = spelling.strip(symbols).lower()
        ps = pronounciation.split()
        ps2 = [p.strip(symbols) for p in ps]
        self.p = ' '.join(ps2)        
        self.x = False
        self.xx = False
        self.xIndex = 0
        if 'x' in self.word:
            self.x = True
            if 'xx' in self.word:
                self.xx = True
                self.s = self.word.replace('xx', 'ks')
            else:
                self.xIndex = self.word.index('x')
                if self.xIndex == 0:
                    self.s = self.word.replace('x', 'z')
                elif self.xIndex == len(self.word) - 1 and ps2[-1] == 'OW':
                    self.s = self.word.replace('x', '')
                elif self.word[self.xIndex - 1] in 'aeiou' and self.xIndex != len(self.word) - 1 and self.word[self.xIndex + 1] in 'aeiou':
                    self.s = self.word.replace('x', 'gz')
                else:
                    self.s = self.word.replace('x', 'ks')
        else:
            self.s = self.word
    def __str__(self):
        return self.word
    def __repr__(self):
        return self.word
    def atomize(self, v, c):
        current_letters = []
        current_sounds = []
        final = {}
        vows = []
        cons = []
        letter_counter = 0
        while letter_counter < len(self.s):
            current_letter = letter_counter
            while letter_counter < len(self.s) and self.s[letter_counter] in "qwrtypsdfghjklzxcvbnm":
                current_letters.append(self.s[letter_counter])
                letter_counter += 1
            final[current_letter] = ''.join(current_letters)
            current_letters = []
            if letter_counter >= len(self.s):
                break
            current_letter = letter_counter
            while letter_counter < len(self.s) and self.s[letter_counter] in "aeiou":
                current_letters.append(self.s[letter_counter])
                letter_counter += 1
            final[current_letter] = ''.join(current_letters)
            current_letters = []
        self.c = cons
        self.v = vows
        self.f = final
#        for i in self.p:
#            if i in v:
#                pass
#            elif i in c:
#                current_sounds.append(i)
#                self.c[letter_counter].append(current_letters)
#                letter_counter += 1
#            else:
#                print("weirdo ->", i)

# %%
wordObjs = []
for line in cmu:
    wordObjs.append(coolWord(*line.split(maxsplit=1)))

# %%
print(wordObjs[0])
# Out:
# exclamation-point

# %%
wordObjs2 = {line.split(maxsplit=1)[0]: coolWord(*line.split(maxsplit=1)) for line in cmu}

# %%
def getPhoneStructure(word):
    phones = []
    for phone in word.p.split():
        if phone in vowels:
            phones.append('V')
        else:
            phones.append('C')
    return ''.join(phones)

# %%
spellings = {
    'AA': ['o'],
    'AE': ['a'],
    'AH': ['u'],
    'AO': ['o'],
    'AW': ['ou'],
    'AX': ['a'],
    'AXR': ['er'],
    'AY': ['i'],
    'EH': ['e'],
    'ER': ['ir'],
    'EY': ['ai'],
    'IH': ['i'],
    'IX': ['e'],
    'IY': ['ea'],
    'OW': ['oa'],
    'OY': ['oy'],
    'UH': ['oo'],
    'UW': ['oo'],
    'UX': ['u'],
    'B': ['b'],
    'CH': ['ch'],
    'D': ['d'],
    'DX': ['tt'],
    'EL': ['le'],
    'EM': ['m'],
    'EN': ['on'],
    'F': ['f'],
    'G': ['g'],
    'H': ['h'],
    'HH': ['h'],
    'JH': ['j'],
    'K': ['k'],
    'L': ['l'],
    'M': ['m'],
    'N': ['n'],
    'NX': ['ng'],
    'NG': ['ng'],
    'P': ['p'],
    'Q': ['-'],
    'R': ['r'],
    'S': ['s'],
    'SH': ['sh'],
    'T': ['t'],
    'TH': ['th'],
    'V': ['v'],
    'W': ['w'],
    'WH': ['wh'],
    'Y': ['y'],
    'Z': ['z'],
    'ZH': ['s']
}

# %%
wordObjs2 = {word: wordObjs2[word] for word in wordObjs2 if len(wordObjs2[word].p.split()) < 2 * len(word)}

# %%
threeLetter = [wordObjs2[word] for word in wordObjs2 if len(wordObjs2[word].s) == 3]

# %%
twoLetter = [wordObjs2[word] for word in wordObjs2 if len(wordObjs2[word].s) == 2]

# %%
def permute(word, graphs):
    for i in range(len(word)):

# %%
baseSpellings = {
    'AA': ['o'],
    'AE': ['a'],
    'AH': ['u', 'o'],
    'AO': ['o'],
    'AW': ['ou'],
    'AX': ['a'],
    'AXR': ['er'],
    'AY': ['i'],
    'EH': ['e'],
    'ER': ['ir'],
    'EY': ['ai'],
    'IH': ['i'],
    'IX': ['e'],
    'IY': ['ea'],
    'OW': ['oa'],
    'OY': ['oy'],
    'UH': ['oo'],
    'UW': ['oo'],
    'UX': ['u'],
    'B': ['b'],
    'CH': ['ch'],
    'D': ['d'],
    'DX': ['tt'],
    'EL': ['le'],
    'EM': ['m'],
    'EN': ['on'],
    'F': ['f'],
    'G': ['g'],
    'H': ['h'],
    'HH': ['h'],
    'JH': ['j'],
    'K': ['k'],
    'L': ['l'],
    'M': ['m'],
    'N': ['n'],
    'NX': ['ng'],
    'NG': ['ng'],
    'P': ['p'],
    'Q': ['-'],
    'R': ['r'],
    'S': ['s'],
    'SH': ['sh'],
    'T': ['t'],
    'TH': ['th'],
    'V': ['v'],
    'W': ['w'],
    'WH': ['wh'],
    'Y': ['y'],
    'Z': ['z'],
    'ZH': ['s']
}

# %%
spellings = {
    'AA': ['o'],
    'AE': ['a'],
    'AH': ['u'],
    'AO': ['o'],
    'AW': ['ou'],
    'AX': ['a'],
    'AXR': ['er'],
    'AY': ['i'],
    'EH': ['e'],
    'ER': ['ir'],
    'EY': ['ai'],
    'IH': ['i'],
    'IX': ['e'],
    'IY': ['ea'],
    'OW': ['oa'],
    'OY': ['oy'],
    'UH': ['oo'],
    'UW': ['oo'],
    'UX': ['u'],
    'B': ['b'],
    'CH': ['ch'],
    'D': ['d'],
    'DX': ['tt'],
    'EL': ['le'],
    'EM': ['m'],
    'EN': ['on'],
    'F': ['f'],
    'G': ['g'],
    'H': ['h'],
    'HH': ['h'],
    'JH': ['j'],
    'K': ['k'],
    'L': ['l'],
    'M': ['m'],
    'N': ['n'],
    'NX': ['ng'],
    'NG': ['ng'],
    'P': ['p'],
    'Q': ['-'],
    'R': ['r'],
    'S': ['s'],
    'SH': ['sh'],
    'T': ['t'],
    'TH': ['th'],
    'V': ['v'],
    'W': ['w'],
    'WH': ['wh'],
    'Y': ['y'],
    'Z': ['z'],
    'ZH': ['s']
}

# %%
len(twoLetter)
# Out:
# 233

# %%
for word in twoLetter:
    news = spell(word)
    print(f"{word.s.lower()}: {word.p}: {news}")
    if word.s.lower() != news:
        break
# Out:
# em: AH M: ['u', 'm']

# %%
print(spell(wordObjs2['BY']))
# Out:
# ['b', 'i']

# %%
def spell2(word):
    phones = word.p.split()
    spelling = []
    
    while ''.join(spelling) != word.s:
        spelling = []
        for p in phones:
            pass
            #if ''.join(spelling + spellings[p][0]

# %%
print(len(''.join([])))
# Out:
# 0

# %%
from time import sleep
from copy import copy

def sideSpell(word, phones, spellings, polarity):
    currentSpell = []
    for p in phones:
        oldLen = len(currentSpell)
        for s in spellings[p]:
            newSpell = copy(currentSpell)
            if not polarity:
                newSpell.append(s)
                if word.s.startswith(''.join(newSpell)):
                    currentSpell.append(s)
                    break
            else:
                newSpell.insert(0, s)
                if word.s.endswith(''.join(newSpell)):
                    currentSpell.insert(0, s)
                    break                
        if len(currentSpell) == oldLen:
            break
    return currentSpell

def spell3(word, spellings):
    word.s = word.s.lower()
    if not word.s.isalnum():
        print("bad characters", word.s)
        return False
    print(word)
    phones = word.p.split()
    if len(word.s) < len(phones):
        print("too long!", word.s, phones)
        return False
    if word.s[:-2] == 'le' and phones[:-2] == ['AH', 'L'] and word.s[-3] not in ['aeiou']:
        phones.append(phones.pop[-2])
        print("special case: L")
    rphones = copy(phones)
    rphones.reverse()
    print("phones", phones, rphones)
    frontSpell = sideSpell(word, phones, spellings, 0)
    backSpell = sideSpell(word, rphones, spellings, 1)
    print("front & back", frontSpell, backSpell)
    if '' in frontSpell:
        frontSpell.remove('')
    if '' in backSpell:
        backSpell.remove('')
    if frontSpell == backSpell and ''.join(frontSpell) == word.s:
        print('yay!')
        return True
    missingG = word.s.removeprefix(''.join(frontSpell)).removesuffix(''.join(backSpell))
    if not missingG:
        missingG = backSpell[0]
    print("missing grapheme", missingG)
    if len(frontSpell + backSpell) > len(phones):
            #print(word, frontSpell, len(frontSpell))
            #print(backSpell, len(backSpell))
            #print(phones)
            print("too long")
            del backSpell[0]
    if len(frontSpell + backSpell) < len(phones):
        try:
            missingP = phones[len(frontSpell)]
            print("missing phoneme (clean)", missingP)
            spellings[missingP].append(missingG)
        except IndexError as e:
            print(word, frontSpell, len(frontSpell))
            print(backSpell, len(backSpell))
            print(phones)
            raise e
    else:
        missingP = phones[len(frontSpell) - 1]
        print("missing phoneme (overlap)", missingP)
        try:
            spellings[missingP].append(''.join((frontSpell[-1], missingG) if frontSpell else (missingG, backSpell[0])))
            print(''.join((frontSpell[-1], missingG) if frontSpell else (missingG, backSpell[0])))
        except IndexError as e:
            print(word, frontSpell, len(frontSpell))
            print(backSpell, len(backSpell))
            print(phones)
            print(missingP)
            raise e

def learn(spellings, words):
    for word in words:
        spell3(word, spellings)
        print(word, word.p)
        break
    return spellings

# %%
def clean(aDict):
    for key in aDict:
        while '' in aDict[key]:
            aDict[key].remove('')

# %%
from random import choice

spell3(choice(twoLetter), spellings)
clean(spellings)
# Out:
# um
# phones ['AH', 'M'] ['M', 'AH']
# front & back ['u', 'm'] ['u', 'm']
# yay!

# %%
spellings
# Out:
# {'AA': ['o'],
#  'AE': ['a'],
#  'AH': ['u'],
#  'AO': ['o'],
#  'AW': ['ou'],
#  'AX': ['a'],
#  'AXR': ['er'],
#  'AY': ['i'],
#  'EH': ['e'],
#  'ER': ['ir'],
#  'EY': ['ai'],
#  'IH': ['i'],
#  'IX': ['e'],
#  'IY': ['ea'],
#  'OW': ['oa'],
#  'OY': ['oy'],
#  'UH': ['oo'],
#  'UW': ['oo'],
#  'UX': ['u'],
#  'B': ['b'],
#  'CH': ['ch'],
#  'D': ['d'],
#  'DX': ['tt'],
#  'EL': ['le'],
#  'EM': ['m'],
#  'EN': ['on'],
#  'F': ['f'],
#  'G': ['g'],
#  'H': ['h'],
#  'HH': ['h'],
#  'JH': ['j'],
#  'K': ['k'],
#  'L': ['l'],
#  'M': ['m'],
#  'N': ['n'],
#  'NX': ['ng'],
#  'NG': ['ng'],
#  'P': ['p'],
#  'Q': ['-'],
#  'R': ['r'],
#  'S': ['s'],
#  'SH': ['sh'],
#  'T': ['t'],
#  'TH': ['th'],
#  'V': ['v'],
#  'W': ['w'],
#  'WH': ['wh'],
#  'Y': ['y'],
#  'Z': ['z'],
#  'ZH': ['s']}

# %%
learn(spellings, twoLetter)
# Out:
# em
# phones ['AH', 'M'] ['M', 'AH']
# front & back [] ['m']
# missing grapheme e
# missing phoneme (clean) AH
# em AH M
# {'AA': ['o'],
#  'AE': ['a'],
#  'AH': ['u', 'e'],
#  'AO': ['o'],
#  'AW': ['ou'],
#  'AX': ['a'],
#  'AXR': ['er'],
#  'AY': ['i'],
#  'EH': ['e'],
#  'ER': ['ir'],
#  'EY': ['ai'],
#  'IH': ['i'],
#  'IX': ['e'],
#  'IY': ['ea'],
#  'OW': ['oa'],
#  'OY': ['oy'],
#  'UH': ['oo'],
#  'UW': ['oo'],
#  'UX': ['u'],
#  'B': ['b'],
#  'CH': ['ch'],
#  'D': ['d'],
#  'DX': ['tt'],
#  'EL': ['le'],
#  'EM': ['m'],
#  'EN': ['on'],
#  'F': ['f'],
#  'G': ['g'],
#  'H': ['h'],
#  'HH': ['h'],
#  'JH': ['j'],
#  'K': ['k'],
#  'L': ['l'],
#  'M': ['m'],
#  'N': ['n'],
#  'NX': ['ng'],
#  'NG': ['ng'],
#  'P': ['p'],
#  'Q': ['-'],
#  'R': ['r'],
#  'S': ['s'],
#  'SH': ['sh'],
#  'T': ['t'],
#  'TH': ['th'],
#  'V': ['v'],
#  'W': ['w'],
#  'WH': ['wh'],
#  'Y': ['y'],
#  'Z': ['z'],
#  'ZH': ['s']}

# %%
for i in twoLetter:
    print(i, i.p)
# Out:
# em AH M
# aa EY EY
# ab AE B
# ac EY S IY
# ad AE D
# ae EY
# ag AE G
# ag EY G IY
# ah AA
# ai AY
# ai EY AY
# al AE L
# al AE L
# al AE L AH B AE M AH
# am AE M
# am EY EH M
# an AE N
# an AH N
# ap EY P IY
# ar AA R
# as AE Z
# as EH Z
# at AE T
# au OW
# aux OW
# av EY V IY
# aw AO
# ay EY
# ay AY
# ba B IY EY
# ba B AA
# be B IY
# be B IY
# bi B AY
# bo B OW
# by B AY
# ca K AH
# ca S IY EY
# ca K AA
# ce S IY IY
# co K OW
# co K OW
# co K AH P AH N IY
# co S IY OW T UW
# cy S AY
# da D AA
# da D IY EY
# de D IY
# de D EY
# de D AH
# di D IY
# di D AY
# do D UW
# dr D AA K T ER
# dr D R AY V
# dr D AA K T ER
# du D UW
# du D AH
# eb EH B
# ed EH D
# ee IY IY
# eh EH
# ek EH K
# ek IY K EY
# el EH L
# em EH M
# en EH N
# er ER
# es EH S
# et EH T
# ev EH V
# fe F EY
# fi F AY
# fi F IY
# fu F UW
# ga G AA
# ga JH IY EY
# ga JH AO R JH AH
# go G OW
# gu G UW
# ha HH AA
# he HH IY
# hi HH AY
# hm HH AH M
# ho HH OW
# hu HH UW
# hy HH AY
# ia IY AH
# ib IH B
# ib AY B IY
# id IH D
# id AY D IY
# if IH F
# il IH L
# im IH M
# in IH N
# in IH N
# in IH N
# in IH N CH
# io AY OW
# ip AY P IY
# ip IH P
# is IH Z
# is IH Z
# it IH T
# it IH T
# ja Y AA
# je JH IY
# ji JH IY
# jo JH OW
# jr JH UW N ER
# ju JH UW
# ka K AA
# ke K EH
# ki K IY
# ko K OW
# ku K UW
# la L AA
# le L AH
# li L IY
# ln L EY N
# lo L OW
# lu L UW
# ly L AY
# ma M AA
# mc M IH K
# mc EH M S IY
# me M IY
# mi M IY
# mo M OW
# mr M IH S T ER
# ms M IH Z
# ms M IH Z
# mt EH M T IY
# mu M UW
# my M AY
# na N AA
# ne N IY
# ne N EY
# ng EH NG
# ng IH NG
# ni N IY
# no N OW
# nu N UW
# of AH V
# of AH V
# og AA G
# oh OW
# oi OY
# oj OW JH EY
# ok OW K EY
# ol OW L
# om AO M
# on AA N
# on AO N
# op AA P
# op AO P
# or AO R
# or ER
# os AA S
# ot AO T
# ot OW T IY
# ou UW
# ow OW
# ow AW
# oy OY
# oz AA Z
# pa P AA
# pi P AY
# po P OW
# pu P UW
# qi K IY
# qu K UW
# ra R AA
# re R EY
# re R IY
# ro R OW
# ru R UW
# ru AA R Y UW
# sa S AA
# se S EY
# si S IY
# so S OW
# sr S IH S T ER
# st S T R IY T
# st S EY N T
# su S UW
# sy S AY
# ta T AA
# te T IY
# ti T IY
# to T UW
# to T IH
# to T AH
# tu T UW
# tv T EH L AH V IH ZH AH N
# ty T AY
# uh AH
# ul AH L
# um AH M
# un AH N
# un Y UW EH N
# up AH P
# ur ER
# us AH S
# us Y UW EH S
# uy UW IY
# uy Y UW W AY
# ve V IY
# vi V AY
# vi V IY
# vo V OW
# vs V ER S AH Z
# vu V UW
# vy V AY
# wa W AA
# we W IY
# wm D AH B AH Y UW EH M
# wo W OW
# wo HH W OW
# ws D AH B Y AH EH S
# wu W UW
# wy W EY
# xi SH IY
# xu Z UW
# ya Y AA
# ye Y IY
# ye Y EH
# yi Y IY
# yo Y OW
# yu Y UW
# ze Z EY
# zi Z IY

# %% [markdown]
# 10/29
#
# So. It does mostly work.
#
# But.
#
# The presence of abbreviations in the dataset means that it contains non-phonetic transcriptions. For example, one pronouncation of "AL" is the full phonetic spelling of Alabama.
#
# (also "MR" sounds like "mister" according to the dictionary)
#
# Currently, the code just refuses to analyze words with more phonemes than letters. This assumes that the only letter in English that can represent two distinct phones in succession is 'x', and that my attempt to account for x works. That seems to hold, though I haven't tested it on any words with more than three letters yet.
#
# I did fail to account for another edge case though: the """word""" 'ng'. According to this version of the CMUPD, 'ng' can be pronounced 'IH NG'. This totally bypasses my attempt to check edge cases: the word is two letters long, so it doesn't have more phones than letters.
#
# LIGHTBULB MOMENT: it has no vowel letter, which means (for our purposes) it isn't a valid pronouncable English word! So I just need to find a reasonably efficient way of checking if a vowel is in a word and build that check into my code!
#
# I also plan to add a method of tracking examples of grapheme usage, which should help with explaining the solutions to its puzzles.
#
# _oh right i'm building a puzzle generator_

# %% [markdown]
# NOTE: this fix does not account for """words""" like 'aa' -- pronounced /EY EY/ --, so my code learned that 'aa' is a valid spelling of /EY/. This actually does appear in fringe cases, like Baal, so maybe this is fine. Will add further comment if any other bad examples happen.
#
# Actually, """words""" like 'er' pronounced /ER/ represent an intended example of the above result.
#
# _at least I think I intended it_

# %% [markdown]
# Well I did find another problem word, but nothing to do with the previous comment. 'of' posed a problem. My code does not start off knowing that 'o' can be pronounced /AH/, or that 'f' can be /v/. So it can't differentiate between both new spellings, and learns that /AH/ can be spelled 'of'. I'll try just adding that pronunciation of 'o' in at the beginning, but obviously this isn't ideal, nor is it consistent. Depending on what order the dictionary of words happens to be in, it'll learn spellings at different times, potentially causing this kind of mistake for different words each time. I am also unsure at this stage whether this is an unlikely occurrence, or if I'll need to build in more knowledge beforehand, which I wanted to minimize.
#
# Also I realized I forgot to mention another issue from earlier. After running my code through every two-letter word and learning each new spelling, the lists of spellings for each phoneme were cluttered with empty strings. As a solution, I just added a function to remove those, but I need to figure out why that happens in the first place.

# %%
## from time import sleep
from copy import copy

def sideSpell(word, phones, spells, polarity):
    currentSpell = []
    for p in phones:
        oldLen = len(currentSpell)
        for s in spells[p]:
            newSpell = copy(currentSpell)
            if not polarity:
                newSpell.append(s.g)
                if word.s.startswith(''.join([a if not isinstance(a, graphExample) else a.g for a in newSpell])):
                    currentSpell.append(s)
                    break
            else:
                newSpell.insert(0, s.g)
                if word.s.endswith(''.join([a if not isinstance(a, graphExample) else a.g for a in newSpell])):
                    currentSpell.insert(0, s)
                    break                
        if len(currentSpell) == oldLen:
            break
    return currentSpell

def spell3(word, spellings, exLen=4, debug=False):
    word.s = word.s.lower()
    if not word.s.isalnum():
        if debug:
            print("bad characters", word.s)
        return False
    if debug:
        print(word)
    phones = word.p.split()
    if len(word.s) < len(phones):
        if debug:
            print("too long!", word.s, phones)
        return False
    if not set(word.s) & set('aeiouy'):
        if debug:
            print("no vowels -> not a word!", word.s, phones)
        return False
    if word.s[:-2] == 'le' and phones[:-2] == ['AH', 'L'] and word.s[-3] not in ['aeiou']:
        phones.append(phones.pop[-2])
        if debug:
            print("special case: L")
    rphones = copy(phones)
    rphones.reverse()
    if debug:
        print("phones", phones, rphones)
    frontSpell = sideSpell(word, phones, spellings, 0)
    frontStr = [a.g for a in frontSpell]
    backSpell = sideSpell(word, rphones, spellings, 1)
    backStr = [a.g for a in backSpell]
    if debug:
        print("front & back", frontSpell, backSpell)
    if '' in frontSpell:
        frontSpell.remove('')
    if '' in backSpell:
        backSpell.remove('')
    if frontSpell == backSpell and ''.join(frontStr) == word.s:
        if debug:
            print('yay!')
            print(word, frontSpell, len(frontSpell))
            print(backSpell, len(backSpell))
            print(phones)
        exPhone = choice(phones)
        g = frontSpell[phones.index(exPhone)]
        p = spellings[exPhone]
        exGraph = p[p.index(g)]
        if len(word.s) == exLen and not exGraph.set:
            exGraph.setExample(word)
        return True
    missingG = graphExample(word.s.removeprefix(''.join(frontStr)).removesuffix(''.join(backStr)), isX=word.x)
    #if not missingG.g:
    #    missingG = backSpell[0]
    if debug:
        print("missing grapheme", missingG)
    if len(frontSpell + backSpell) > len(phones):
            #print(word, frontSpell, len(frontSpell))
            #print(backSpell, len(backSpell))
            #print(phones)
            if debug:
                print("too long")
            del backSpell[0]
    if len(frontSpell + backSpell) < len(phones):
        try:
            missingP = phones[len(frontSpell)]
            if debug:
                print("missing phoneme (clean)", missingP)
            if len(word.s) == exLen and not missingG.set:
                missingG.setExample(word)        
            spellings[missingP].append(missingG)    
        except IndexError as e:
            if debug:
                print(word, frontSpell, len(frontSpell))
                print(backSpell, len(backSpell))
                print(phones)
            raise e
    else:
        missingP = phones[len(frontSpell) - 1]
        if debug:
            print("missing phoneme (overlap)", missingP)
        try:
            newG = graphExample(''.join((frontStr[-1], missingG.g) if frontStr else (missingG.g, backStr[0])), isX = missingG.g.count('x') or (frontStr[-1].count('x') if frontStr else backStr[0].count('x')))
            if len(word.s) == exLen and not newG.set:
                newG.setExample(word)  
            spellings[missingP].append(newG)
            if debug:
                print(newG)
        except IndexError as e:
            if debug:
                print(word, frontSpell, len(frontSpell))
                print(backSpell, len(backSpell))
                print(phones)
                print(missingP)
            raise e

def learn3(spellings, words, exLen=4, debug=False):
    newSpells = {s: copy(spellings[s]) for s in spellings}
    for word in words:
        spell3(word, newSpells, exLen=exLen, debug=debug)
        if debug:
            print(word, word.p)
        #break
    return newSpells

# %%
print(bool(set('geoff') & set('aeiou')))
# Out:
# True

# %%
baseSpellings = {
    'AA': ['o'],
    'AE': ['a'],
    'AH': ['u', 'o'],
    'AO': ['o'],
    'AW': ['ou'],
    'AX': ['a'],
    'AXR': ['er'],
    'AY': ['i'],
    'EH': ['e'],
    'ER': ['ir'],
    'EY': ['ai'],
    'IH': ['i'],
    'IX': ['e'],
    'IY': ['ea'],
    'OW': ['oa'],
    'OY': ['oy'],
    'UH': ['oo'],
    'UW': ['oo'],
    'UX': ['u'],
    'B': ['b'],
    'CH': ['ch'],
    'D': ['d'],
    'DX': ['tt'],
    'EL': ['le'],
    'EM': ['m'],
    'EN': ['on'],
    'F': ['f'],
    'G': ['g'],
    'H': ['h'],
    'HH': ['h'],
    'JH': ['j'],
    'K': ['k'],
    'L': ['l'],
    'M': ['m'],
    'N': ['n'],
    'NX': ['ng'],
    'NG': ['ng'],
    'P': ['p'],
    'Q': ['-'],
    'R': ['r'],
    'S': ['s'],
    'SH': ['sh'],
    'T': ['t'],
    'TH': ['th'],
    'V': ['v'],
    'W': ['w'],
    'WH': ['wh'],
    'Y': ['y'],
    'Z': ['z'],
    'ZH': ['s']
}

# %%
def initSpellings(plain):
    ans = {p: [graphExample(a, isX=bool(a.count('x'))) for a in plain[p]] for p in plain}
    return ans

# %%
coolSpellings = initSpellings(baseSpellings)

# %%
class graphExample:
    def __init__(self, grapheme, isX=False):
        self.g = grapheme
        self.set = False
        self.isx = isX
        self.x = 'x' if isX else None

    def __str__(self):
        try:
            return f"'{self.g if not self.isx else self.x}' in '{self.w}'"
        except AttributeError as e:
            return self.g if not self.isx else self.x

    def __repr__(self):
        return self.__str__()

    def __eq__(self, other):
        if isinstance(other, str):
            return self.g == other
        elif isinstance(other, graphExample):
            return self.g == other.g
        return False

    def __hash__(self):
        return self.g.__hash__() if not self.isx else self.x.__hash__()

    def setExample(self, ex):
        self.w = ex
        self.set = True

# %%
test1 = learn3(coolSpellings, twoLetter, exLen=2)

# %%
test1
# Out:
# {'AA': ['o' in 'og', 'ah' in 'ah', 'a' in 'ar'],
#  'AE': ['a' in 'ad'],
#  'AH': ['u' in 'um', 'o' in 'of', 'e' in 'em', 'a' in 'an', 'uh' in 'uh'],
#  'AO': ['o' in 'om', 'aw' in 'aw'],
#  'AW': [ou, 'ow' in 'ow'],
#  'AX': [a],
#  'AXR': [er],
#  'AY': ['i' in 'fi', 'ai' in 'ai', 'ay' in 'ay', 'y' in 'by'],
#  'EH': ['e' in 'eb', 'a' in 'as', 'eh' in 'eh'],
#  'ER': [ir, 'er' in 'er', 'or' in 'or', 'ur' in 'ur'],
#  'EY': [ai,
#   'aa' in 'aa',
#   'ae' in 'ae',
#   'ai' in 'ai',
#   'ay' in 'ay',
#   'e' in 'de',
#   'y' in 'wy'],
#  'IH': ['i' in 'if', 'o' in 'to'],
#  'IX': [e],
#  'IY': [ea, 'e' in 'be', 'i' in 'di', 'y' in 'uy'],
#  'OW': [oa, 'au' in 'au', 'o' in 'bo', 'oh' in 'oh', 'ow' in 'ow'],
#  'OY': ['oy' in 'oy', 'oi' in 'oi'],
#  'UH': [oo],
#  'UW': [oo, 'o' in 'do', 'u' in 'du', 'o' in 'ou'],
#  'UX': [u],
#  'B': ['b' in 'ab'],
#  'CH': [ch],
#  'D': ['d' in 'da'],
#  'DX': [tt],
#  'EL': [le],
#  'EM': [m],
#  'EN': [on],
#  'F': ['f' in 'fe'],
#  'G': ['g' in 'ag'],
#  'H': [h],
#  'HH': ['h' in 'ha'],
#  'JH': ['j' in 'ji'],
#  'K': ['k' in 'ka', 'c' in 'ca', 'q' in 'qi'],
#  'L': ['l' in 'al'],
#  'M': ['m' in 'am'],
#  'N': ['n' in 'an'],
#  'NX': [ng],
#  'NG': [ng],
#  'P': ['p' in 'pa'],
#  'Q': [-],
#  'R': ['r' in 're'],
#  'S': ['s' in 'es', 'c' in 'cy'],
#  'SH': [sh, 'x' in 'xi'],
#  'T': ['t' in 'at'],
#  'TH': [th],
#  'V': ['v' in 'vi', 'f' in 'of'],
#  'W': [w],
#  'WH': [wh],
#  'Y': ['y' in 'ya', 'j' in 'ja'],
#  'Z': ['z' in 'oz', 's' in 'as'],
#  'ZH': [s]}

# %%
def validate(spell1, spell2):
    differences = {}
    for phone in spell1:
        setDiffs = set(spell1[phone]) ^ set(spell2[phone])
        if setDiffs:
            differences[phone] = [spell1[phone], spell2[phone]]
    if differences:
        return differences

# %%
from random import sample

def get_mistakes(baseSpells, words, completeSpells, exLen=4):
    generation = 0
    while generation < 100:
        testSpells = learn3(baseSpells, sample(words, len(words)), exLen=exLen)
        check = validate(completeSpells, testSpells)
        if check:
            return generation, check
        generation += 1
    return 'nope'

# %%
coolSpellings
# Out:
# {'AA': ['o' in 'og'],
#  'AE': ['a' in 'ad'],
#  'AH': ['u' in 'um', 'o' in 'of'],
#  'AO': ['o' in 'om'],
#  'AW': [ou],
#  'AX': [a],
#  'AXR': [er],
#  'AY': ['i' in 'fi'],
#  'EH': ['e' in 'eb'],
#  'ER': [ir],
#  'EY': [ai],
#  'IH': ['i' in 'if'],
#  'IX': [e],
#  'IY': [ea],
#  'OW': [oa],
#  'OY': ['oy' in 'oy'],
#  'UH': [oo],
#  'UW': [oo],
#  'UX': [u],
#  'B': ['b' in 'ab'],
#  'CH': [ch],
#  'D': ['d' in 'da'],
#  'DX': [tt],
#  'EL': [le],
#  'EM': [m],
#  'EN': [on],
#  'F': ['f' in 'fe'],
#  'G': ['g' in 'ag'],
#  'H': [h],
#  'HH': ['h' in 'ha'],
#  'JH': ['j' in 'ji'],
#  'K': ['k' in 'ka'],
#  'L': ['l' in 'al'],
#  'M': ['m' in 'am'],
#  'N': ['n' in 'an'],
#  'NX': [ng],
#  'NG': [ng],
#  'P': ['p' in 'pa'],
#  'Q': [-],
#  'R': ['r' in 're'],
#  'S': ['s' in 'es'],
#  'SH': [sh],
#  'T': ['t' in 'at'],
#  'TH': [th],
#  'V': ['v' in 'vi'],
#  'W': [w],
#  'WH': [wh],
#  'Y': ['y' in 'ya'],
#  'Z': ['z' in 'oz'],
#  'ZH': [s]}

# %%
coolSpellings = initSpellings(baseSpellings)

# %%
test2 = learn3(test1, threeLetter, exLen=3, debug=True)
# Out:
# kay
# phones ['K', 'EY'] ['EY', 'K']
# front & back ['k' in 'ka', 'ay' in 'ay'] ['k' in 'ka', 'ay' in 'ay']
# yay!
# kay ['k' in 'ka', 'ay' in 'ay'] 2
# ['k' in 'ka', 'ay' in 'ay'] 2
# ['K', 'EY']
# kay K EY
# til
# phones ['T', 'IH', 'L'] ['L', 'IH', 'T']
# front & back ['t' in 'at', 'i' in 'if', 'l' in 'al'] ['t' in 'at', 'i' in 'if', 'l' in 'al']
# yay!
# til ['t' in 'at', 'i' in 'if', 'l' in 'al'] 3
# ['t' in 'at', 'i' in 'if', 'l' in 'al'] 3
# ['T', 'IH', 'L']
# til T IH L
# tis
# phones ['T', 'IH', 'Z'] ['Z', 'IH', 'T']
# front & back ['t' in 'at', 'i' in 'if', 's' in 'as'] ['t' in 'at', 'i' in 'if', 's' in 'as']
# yay!
# tis ['t' in 'at', 'i' in 'if', 's' in 'as'] 3
# ['t' in 'at', 'i' in 'if', 's' in 'as'] 3
# ['T', 'IH', 'Z']
# tis T IH Z
# dot
# phones ['D', 'AA', 'T'] ['T', 'AA', 'D']
# front & back ['d' in 'da', 'o' in 'og', 't' in 'at'] ['d' in 'da', 'o' in 'og', 't' in 'at']
# yay!
# dot ['d' in 'da', 'o' in 'og', 't' in 'at'] 3
# ['d' in 'da', 'o' in 'og', 't' in 'at'] 3
# ['D', 'AA', 'T']
# dot D AA T
# bad characters a's
# a's EY Z
# bad characters a.d
# a.d EY D IY
# bad characters a.m
# a.m EY EH M
# bad characters a.s
# a.s EY Z
# aah
# phones ['AA'] ['AA']
# front & back ['a' in 'ar'] ['ah' in 'ah']
# missing grapheme
# too long
# missing phoneme (overlap) AA
# 'a' in 'aah'
# aah AA
# aba
# too long! aba ['EY', 'B', 'IY', 'EY']
# aba EY B IY EY
# abc
# too long! abc ['EY', 'B', 'IY', 'S', 'IY']
# abc EY B IY S IY
# abd
# too long! abd ['EY', 'B', 'IY', 'D', 'IY']
# abd EY B IY D IY
# abe
# phones ['EY', 'B'] ['B', 'EY']
# front & back [] []
# missing grapheme abe
# missing phoneme (clean) EY
# abe EY B
# abo
# phones ['AA', 'B', 'OW'] ['OW', 'B', 'AA']
# front & back ['a' in 'ar', 'b' in 'ab', 'o' in 'bo'] ['a' in 'ar', 'b' in 'ab', 'o' in 'bo']
# yay!
# abo ['a' in 'ar', 'b' in 'ab', 'o' in 'bo'] 3
# ['a' in 'ar', 'b' in 'ab', 'o' in 'bo'] 3
# ['AA', 'B', 'OW']
# abo AA B OW
# abs
# too long! abs ['EY', 'B', 'IY', 'EH', 'S']
# abs EY B IY EH S
# abs
# phones ['AE', 'B', 'Z'] ['Z', 'B', 'AE']
# front & back ['a' in 'ad', 'b' in 'ab', 's' in 'as'] ['a' in 'ad', 'b' in 'ab', 's' in 'as']
# yay!
# abs ['a' in 'ad', 'b' in 'ab', 's' in 'as'] 3
# ['a' in 'ad', 'b' in 'ab', 's' in 'as'] 3
# ['AE', 'B', 'Z']
# abs AE B Z
# abt
# phones ['AE', 'B', 'T'] ['T', 'B', 'AE']
# front & back ['a' in 'ad', 'b' in 'ab', 't' in 'at'] ['a' in 'ad', 'b' in 'ab', 't' in 'at']
# yay!
# abt ['a' in 'ad', 'b' in 'ab', 't' in 'at'] 3
# ['a' in 'ad', 'b' in 'ab', 't' in 'at'] 3
# ['AE', 'B', 'T']
# abt AE B T
# abt
# too long! abt ['EY', 'B', 'IY', 'T', 'IY']
# abt EY B IY T IY
# abu
# phones ['AE', 'B', 'UW'] ['UW', 'B', 'AE']
# front & back ['a' in 'ad', 'b' in 'ab', 'u' in 'du'] ['a' in 'ad', 'b' in 'ab', 'u' in 'du']
# yay!
# abu ['a' in 'ad', 'b' in 'ab', 'u' in 'du'] 3
# ['a' in 'ad', 'b' in 'ab', 'u' in 'du'] 3
# ['AE', 'B', 'UW']
# abu AE B UW
# aca
# phones ['AE', 'K', 'AH'] ['AH', 'K', 'AE']
# front & back ['a' in 'ad', 'c' in 'ca', 'a' in 'an'] ['a' in 'ad', 'c' in 'ca', 'a' in 'an']
# yay!
# aca ['a' in 'ad', 'c' in 'ca', 'a' in 'an'] 3
# ['a' in 'ad', 'c' in 'ca', 'a' in 'an'] 3
# ['AE', 'K', 'AH']
# aca AE K AH
# acc
# too long! acc ['AY', 'S', 'IY', 'S', 'IY']
# acc AY S IY S IY
# ace
# phones ['EY', 'S'] ['S', 'EY']
# front & back [] []
# missing grapheme ace
# missing phoneme (clean) EY
# ace EY S
# ack
# phones ['AE', 'K'] ['K', 'AE']
# front & back ['a' in 'ad', 'c' in 'ca'] ['k' in 'ka']
# missing grapheme
# too long
# missing phoneme (overlap) K
# 'c' in 'ack'
# ack AE K
# acm
# too long! acm ['EY', 'S', 'IY', 'EH', 'M']
# acm EY S IY EH M
# act
# phones ['AE', 'K', 'T'] ['T', 'K', 'AE']
# front & back ['a' in 'ad', 'c' in 'ca', 't' in 'at'] ['a' in 'ad', 'c' in 'ca', 't' in 'at']
# yay!
# act ['a' in 'ad', 'c' in 'ca', 't' in 'at'] 3
# ['a' in 'ad', 'c' in 'ca', 't' in 'at'] 3
# ['AE', 'K', 'T']
# act AE K T
# ada
# phones ['EY', 'D', 'AH'] ['AH', 'D', 'EY']
# front & back [] ['d' in 'da', 'a' in 'an']
# missing grapheme a
# missing phoneme (clean) EY
# ada EY D AH
# add
# phones ['AE', 'D'] ['D', 'AE']
# front & back ['a' in 'ad', 'd' in 'da'] ['d' in 'da']
# missing grapheme
# too long
# missing phoneme (overlap) D
# 'd' in 'add'
# add AE D
# ade
# phones ['EY', 'D'] ['D', 'EY']
# front & back ['a' in 'ada', 'd' in 'da'] []
# missing grapheme e
# missing phoneme (overlap) D
# 'de' in 'ade'
# ade EY D
# ado
# phones ['AH', 'D', 'UW'] ['UW', 'D', 'AH']
# front & back ['a' in 'an', 'd' in 'da', 'o' in 'do'] ['a' in 'an', 'd' in 'da', 'o' in 'do']
# yay!
# ado ['a' in 'an', 'd' in 'da', 'o' in 'do'] 3
# ['a' in 'an', 'd' in 'da', 'o' in 'do'] 3
# ['AH', 'D', 'UW']
# ado AH D UW
# ads
# phones ['AE', 'D', 'Z'] ['Z', 'D', 'AE']
# front & back ['a' in 'ad', 'd' in 'da', 's' in 'as'] ['a' in 'ad', 'd' in 'da', 's' in 'as']
# yay!
# ads ['a' in 'ad', 'd' in 'da', 's' in 'as'] 3
# ['a' in 'ad', 'd' in 'da', 's' in 'as'] 3
# ['AE', 'D', 'Z']
# ads AE D Z
# ads
# phones ['AE', 'D', 'Z'] ['Z', 'D', 'AE']
# front & back ['a' in 'ad', 'd' in 'da', 's' in 'as'] ['a' in 'ad', 'd' in 'da', 's' in 'as']
# yay!
# ads ['a' in 'ad', 'd' in 'da', 's' in 'as'] 3
# ['a' in 'ad', 'd' in 'da', 's' in 'as'] 3
# ['AE', 'D', 'Z']
# ads AE D Z
# ady
# phones ['EY', 'D', 'IY'] ['IY', 'D', 'EY']
# front & back ['a' in 'ada', 'd' in 'da', 'y' in 'uy'] ['a' in 'ada', 'd' in 'da', 'y' in 'uy']
# yay!
# ady ['a' in 'ada', 'd' in 'da', 'y' in 'uy'] 3
# ['a' in 'ada', 'd' in 'da', 'y' in 'uy'] 3
# ['EY', 'D', 'IY']
# ady EY D IY
# adz
# phones ['AE', 'D', 'Z'] ['Z', 'D', 'AE']
# front & back ['a' in 'ad', 'd' in 'da', 'z' in 'oz'] ['a' in 'ad', 'd' in 'da', 'z' in 'oz']
# yay!
# adz ['a' in 'ad', 'd' in 'da', 'z' in 'oz'] 3
# ['a' in 'ad', 'd' in 'da', 'z' in 'oz'] 3
# ['AE', 'D', 'Z']
# adz AE D Z
# aer
# phones ['EH', 'R'] ['R', 'EH']
# front & back ['a' in 'as'] ['e' in 'eb', 'r' in 're']
# missing grapheme
# too long
# missing phoneme (overlap) EH
# 'a' in 'aer'
# aer EH R
# afl
# too long! afl ['EY', 'EH', 'F', 'EH', 'L']
# afl EY EH F EH L
# aft
# phones ['AE', 'F', 'T'] ['T', 'F', 'AE']
# front & back ['a' in 'ad', 'f' in 'fe', 't' in 'at'] ['a' in 'ad', 'f' in 'fe', 't' in 'at']
# yay!
# aft ['a' in 'ad', 'f' in 'fe', 't' in 'at'] 3
# ['a' in 'ad', 'f' in 'fe', 't' in 'at'] 3
# ['AE', 'F', 'T']
# aft AE F T
# aga
# phones ['AA', 'G', 'AH'] ['AH', 'G', 'AA']
# front & back ['a' in 'ar', 'g' in 'ag', 'a' in 'an'] ['a' in 'ar', 'g' in 'ag', 'a' in 'an']
# yay!
# aga ['a' in 'ar', 'g' in 'ag', 'a' in 'an'] 3
# ['a' in 'ar', 'g' in 'ag', 'a' in 'an'] 3
# ['AA', 'G', 'AH']
# aga AA G AH
# age
# phones ['EY', 'JH'] ['JH', 'EY']
# front & back ['a' in 'ada'] []
# missing grapheme ge
# missing phoneme (clean) JH
# age EY JH
# ago
# phones ['AH', 'G', 'OW'] ['OW', 'G', 'AH']
# front & back ['a' in 'an', 'g' in 'ag', 'o' in 'bo'] ['a' in 'an', 'g' in 'ag', 'o' in 'bo']
# yay!
# ago ['a' in 'an', 'g' in 'ag', 'o' in 'bo'] 3
# ['a' in 'an', 'g' in 'ag', 'o' in 'bo'] 3
# ['AH', 'G', 'OW']
# ago AH G OW
# aha
# phones ['AA', 'HH', 'AA'] ['AA', 'HH', 'AA']
# front & back ['ah' in 'ah'] ['a' in 'ar', 'h' in 'ha', 'a' in 'ar']
# missing grapheme a
# too long
# missing phoneme (overlap) AA
# 'aha' in 'aha'
# aha AA HH AA
# ahh
# phones ['AA'] ['AA']
# front & back ['ah' in 'ah'] []
# missing grapheme h
# missing phoneme (overlap) AA
# 'ahh' in 'ahh'
# ahh AA
# ahl
# phones ['AA', 'L'] ['L', 'AA']
# front & back ['ah' in 'ah', 'l' in 'al'] ['ah' in 'ah', 'l' in 'al']
# yay!
# ahl ['ah' in 'ah', 'l' in 'al'] 2
# ['ah' in 'ah', 'l' in 'al'] 2
# ['AA', 'L']
# ahl AA L
# ahn
# phones ['AE', 'N'] ['N', 'AE']
# front & back ['a' in 'ad'] ['n' in 'an']
# missing grapheme h
# missing phoneme (overlap) AE
# 'ah' in 'ahn'
# ahn AE N
# aho
# phones ['AA', 'HH', 'OW'] ['OW', 'HH', 'AA']
# front & back ['ah' in 'ah'] ['a' in 'ar', 'h' in 'ha', 'o' in 'bo']
# missing grapheme o
# too long
# missing phoneme (overlap) AA
# 'aho' in 'aho'
# aho AA HH OW
# ahr
# phones ['AA', 'R'] ['R', 'AA']
# front & back ['ah' in 'ah', 'r' in 're'] ['ah' in 'ah', 'r' in 're']
# yay!
# ahr ['ah' in 'ah', 'r' in 're'] 2
# ['ah' in 'ah', 'r' in 're'] 2
# ['AA', 'R']
# ahr AA R
# ahs
# phones ['AA', 'Z'] ['Z', 'AA']
# front & back ['ah' in 'ah', 's' in 'as'] ['ah' in 'ah', 's' in 'as']
# yay!
# ahs ['ah' in 'ah', 's' in 'as'] 2
# ['ah' in 'ah', 's' in 'as'] 2
# ['AA', 'Z']
# ahs AA Z
# aid
# phones ['EY', 'D'] ['D', 'EY']
# front & back [ai, 'd' in 'da'] [ai, 'd' in 'da']
# yay!
# aid [ai, 'd' in 'da'] 2
# [ai, 'd' in 'da'] 2
# ['EY', 'D']
# aid EY D
# ail
# phones ['EY', 'L'] ['L', 'EY']
# front & back ['ai' in 'aid', 'l' in 'al'] ['ai' in 'aid', 'l' in 'al']
# yay!
# ail ['ai' in 'aid', 'l' in 'al'] 2
# ['ai' in 'aid', 'l' in 'al'] 2
# ['EY', 'L']
# ail EY L
# aim
# phones ['EY', 'M'] ['M', 'EY']
# front & back ['ai' in 'aid', 'm' in 'am'] ['ai' in 'aid', 'm' in 'am']
# yay!
# aim ['ai' in 'aid', 'm' in 'am'] 2
# ['ai' in 'aid', 'm' in 'am'] 2
# ['EY', 'M']
# aim EY M
# air
# phones ['EH', 'R'] ['R', 'EH']
# front & back ['a' in 'as'] ['r' in 're']
# missing grapheme i
# missing phoneme (overlap) EH
# 'ai' in 'air'
# air EH R
# ais
# phones ['AY', 'Z'] ['Z', 'AY']
# front & back ['ai' in 'ai', 's' in 'as'] ['i' in 'fi', 's' in 'as']
# missing grapheme
# too long
# missing phoneme (overlap) Z
# 's' in 'ais'
# ais AY Z
# aja
# phones ['AY', 'AH'] ['AH', 'AY']
# front & back [] ['a' in 'an']
# missing grapheme aj
# missing phoneme (clean) AY
# aja AY AH
# aka
# phones ['AA', 'K', 'AH'] ['AH', 'K', 'AA']
# front & back ['a' in 'ar', 'k' in 'ka', 'a' in 'an'] ['a' in 'ar', 'k' in 'ka', 'a' in 'an']
# yay!
# aka ['a' in 'ar', 'k' in 'ka', 'a' in 'an'] 3
# ['a' in 'ar', 'k' in 'ka', 'a' in 'an'] 3
# ['AA', 'K', 'AH']
# aka AA K AH
# aka
# too long! aka ['EY', 'K', 'EY', 'EY']
# aka EY K EY EY
# akc
# phones ['AE', 'K'] ['K', 'AE']
# front & back ['a' in 'ad', 'k' in 'ka'] ['c' in 'ca']
# missing grapheme
# too long
# missing phoneme (overlap) K
# 'k' in 'akc'
# akc AE K
# ake
# phones ['EY', 'K'] ['K', 'EY']
# front & back ['a' in 'ada', 'k' in 'ka'] []
# missing grapheme e
# missing phoneme (overlap) K
# 'ke' in 'ake'
# ake EY K
# aki
# phones ['AA', 'K', 'IY'] ['IY', 'K', 'AA']
# front & back ['a' in 'ar', 'k' in 'ka', 'i' in 'di'] ['a' in 'ar', 'k' in 'ka', 'i' in 'di']
# yay!
# aki ['a' in 'ar', 'k' in 'ka', 'i' in 'di'] 3
# ['a' in 'ar', 'k' in 'ka', 'i' in 'di'] 3
# ['AA', 'K', 'IY']
# aki AA K IY
# ala
# phones ['AE', 'L', 'AH'] ['AH', 'L', 'AE']
# front & back ['a' in 'ad', 'l' in 'al', 'a' in 'an'] ['a' in 'ad', 'l' in 'al', 'a' in 'an']
# yay!
# ala ['a' in 'ad', 'l' in 'al', 'a' in 'an'] 3
# ['a' in 'ad', 'l' in 'al', 'a' in 'an'] 3
# ['AE', 'L', 'AH']
# ala AE L AH
# ala
# phones ['EY', 'L', 'AH'] ['AH', 'L', 'EY']
# front & back ['a' in 'ada', 'l' in 'al', 'a' in 'an'] ['a' in 'ada', 'l' in 'al', 'a' in 'an']
# yay!
# ala ['a' in 'ada', 'l' in 'al', 'a' in 'an'] 3
# ['a' in 'ada', 'l' in 'al', 'a' in 'an'] 3
# ['EY', 'L', 'AH']
# ala EY L AH
# ale
# phones ['EY', 'L'] ['L', 'EY']
# front & back ['a' in 'ada', 'l' in 'al'] []
# missing grapheme e
# missing phoneme (overlap) L
# 'le' in 'ale'
# ale EY L
# alf
# phones ['AE', 'L', 'F'] ['F', 'L', 'AE']
# front & back ['a' in 'ad', 'l' in 'al', 'f' in 'fe'] ['a' in 'ad', 'l' in 'al', 'f' in 'fe']
# yay!
# alf ['a' in 'ad', 'l' in 'al', 'f' in 'fe'] 3
# ['a' in 'ad', 'l' in 'al', 'f' in 'fe'] 3
# ['AE', 'L', 'F']
# alf AE L F
# ali
# phones ['AA', 'L', 'IY'] ['IY', 'L', 'AA']
# front & back ['a' in 'ar', 'l' in 'al', 'i' in 'di'] ['a' in 'ar', 'l' in 'al', 'i' in 'di']
# yay!
# ali ['a' in 'ar', 'l' in 'al', 'i' in 'di'] 3
# ['a' in 'ar', 'l' in 'al', 'i' in 'di'] 3
# ['AA', 'L', 'IY']
# ali AA L IY
# all
# phones ['AO', 'L'] ['L', 'AO']
# front & back [] ['l' in 'al']
# missing grapheme al
# missing phoneme (clean) AO
# all AO L
# alm
# phones ['AA', 'L', 'M'] ['M', 'L', 'AA']
# front & back ['a' in 'ar', 'l' in 'al', 'm' in 'am'] ['a' in 'ar', 'l' in 'al', 'm' in 'am']
# yay!
# alm ['a' in 'ar', 'l' in 'al', 'm' in 'am'] 3
# ['a' in 'ar', 'l' in 'al', 'm' in 'am'] 3
# ['AA', 'L', 'M']
# alm AA L M
# als
# phones ['AE', 'L', 'Z'] ['Z', 'L', 'AE']
# front & back ['a' in 'ad', 'l' in 'al', 's' in 'as'] ['a' in 'ad', 'l' in 'al', 's' in 'as']
# yay!
# als ['a' in 'ad', 'l' in 'al', 's' in 'as'] 3
# ['a' in 'ad', 'l' in 'al', 's' in 'as'] 3
# ['AE', 'L', 'Z']
# als AE L Z
# alt
# phones ['AA', 'L', 'T'] ['T', 'L', 'AA']
# front & back ['a' in 'ar', 'l' in 'al', 't' in 'at'] ['a' in 'ar', 'l' in 'al', 't' in 'at']
# yay!
# alt ['a' in 'ar', 'l' in 'al', 't' in 'at'] 3
# ['a' in 'ar', 'l' in 'al', 't' in 'at'] 3
# ['AA', 'L', 'T']
# alt AA L T
# alu
# phones ['AA', 'L', 'UW'] ['UW', 'L', 'AA']
# front & back ['a' in 'ar', 'l' in 'al', 'u' in 'du'] ['a' in 'ar', 'l' in 'al', 'u' in 'du']
# yay!
# alu ['a' in 'ar', 'l' in 'al', 'u' in 'du'] 3
# ['a' in 'ar', 'l' in 'al', 'u' in 'du'] 3
# ['AA', 'L', 'UW']
# alu AA L UW
# aly
# phones ['EY', 'L', 'IY'] ['IY', 'L', 'EY']
# front & back ['a' in 'ada', 'l' in 'al', 'y' in 'uy'] ['a' in 'ada', 'l' in 'al', 'y' in 'uy']
# yay!
# aly ['a' in 'ada', 'l' in 'al', 'y' in 'uy'] 3
# ['a' in 'ada', 'l' in 'al', 'y' in 'uy'] 3
# ['EY', 'L', 'IY']
# aly EY L IY
# ama
# too long! ama ['EY', 'EH', 'M', 'EY']
# ama EY EH M EY
# amc
# too long! amc ['EY', 'EH', 'M', 'S', 'IY']
# amc EY EH M S IY
# amd
# too long! amd ['EY', 'EH', 'M', 'D', 'IY']
# amd EY EH M D IY
# ame
# phones ['EY', 'M'] ['M', 'EY']
# front & back ['a' in 'ada', 'm' in 'am'] []
# missing grapheme e
# missing phoneme (overlap) M
# 'me' in 'ame'
# ame EY M
# ami
# phones ['AA', 'M', 'IY'] ['IY', 'M', 'AA']
# front & back ['a' in 'ar', 'm' in 'am', 'i' in 'di'] ['a' in 'ar', 'm' in 'am', 'i' in 'di']
# yay!
# ami ['a' in 'ar', 'm' in 'am', 'i' in 'di'] 3
# ['a' in 'ar', 'm' in 'am', 'i' in 'di'] 3
# ['AA', 'M', 'IY']
# ami AA M IY
# amo
# phones ['AA', 'M', 'OW'] ['OW', 'M', 'AA']
# front & back ['a' in 'ar', 'm' in 'am', 'o' in 'bo'] ['a' in 'ar', 'm' in 'am', 'o' in 'bo']
# yay!
# amo ['a' in 'ar', 'm' in 'am', 'o' in 'bo'] 3
# ['a' in 'ar', 'm' in 'am', 'o' in 'bo'] 3
# ['AA', 'M', 'OW']
# amo AA M OW
# amp
# phones ['AE', 'M', 'P'] ['P', 'M', 'AE']
# front & back ['a' in 'ad', 'm' in 'am', 'p' in 'pa'] ['a' in 'ad', 'm' in 'am', 'p' in 'pa']
# yay!
# amp ['a' in 'ad', 'm' in 'am', 'p' in 'pa'] 3
# ['a' in 'ad', 'm' in 'am', 'p' in 'pa'] 3
# ['AE', 'M', 'P']
# amp AE M P
# amr
# phones ['AA', 'M', 'ER'] ['ER', 'M', 'AA']
# front & back ['a' in 'ar', 'm' in 'am'] []
# missing grapheme r
# missing phoneme (clean) ER
# amr AA M ER
# ams
# phones ['AE', 'M', 'Z'] ['Z', 'M', 'AE']
# front & back ['a' in 'ad', 'm' in 'am', 's' in 'as'] ['a' in 'ad', 'm' in 'am', 's' in 'as']
# yay!
# ams ['a' in 'ad', 'm' in 'am', 's' in 'as'] 3
# ['a' in 'ad', 'm' in 'am', 's' in 'as'] 3
# ['AE', 'M', 'Z']
# ams AE M Z
# amy
# phones ['EY', 'M', 'IY'] ['IY', 'M', 'EY']
# front & back ['a' in 'ada', 'm' in 'am', 'y' in 'uy'] ['a' in 'ada', 'm' in 'am', 'y' in 'uy']
# yay!
# amy ['a' in 'ada', 'm' in 'am', 'y' in 'uy'] 3
# ['a' in 'ada', 'm' in 'am', 'y' in 'uy'] 3
# ['EY', 'M', 'IY']
# amy EY M IY
# ana
# phones ['AA', 'N', 'AH'] ['AH', 'N', 'AA']
# front & back ['a' in 'ar', 'n' in 'an', 'a' in 'an'] ['a' in 'ar', 'n' in 'an', 'a' in 'an']
# yay!
# ana ['a' in 'ar', 'n' in 'an', 'a' in 'an'] 3
# ['a' in 'ar', 'n' in 'an', 'a' in 'an'] 3
# ['AA', 'N', 'AH']
# ana AA N AH
# ana
# phones ['AE', 'N', 'AH'] ['AH', 'N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an', 'a' in 'an'] ['a' in 'ad', 'n' in 'an', 'a' in 'an']
# yay!
# ana ['a' in 'ad', 'n' in 'an', 'a' in 'an'] 3
# ['a' in 'ad', 'n' in 'an', 'a' in 'an'] 3
# ['AE', 'N', 'AH']
# ana AE N AH
# and
# phones ['AH', 'N', 'D'] ['D', 'N', 'AH']
# front & back ['a' in 'an', 'n' in 'an', 'd' in 'da'] ['a' in 'an', 'n' in 'an', 'd' in 'da']
# yay!
# and ['a' in 'an', 'n' in 'an', 'd' in 'da'] 3
# ['a' in 'an', 'n' in 'an', 'd' in 'da'] 3
# ['AH', 'N', 'D']
# and AH N D
# and
# phones ['AE', 'N', 'D'] ['D', 'N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an', 'd' in 'da'] ['a' in 'ad', 'n' in 'an', 'd' in 'da']
# yay!
# and ['a' in 'ad', 'n' in 'an', 'd' in 'da'] 3
# ['a' in 'ad', 'n' in 'an', 'd' in 'da'] 3
# ['AE', 'N', 'D']
# and AE N D
# ane
# phones ['EY', 'N'] ['N', 'EY']
# front & back ['a' in 'ada', 'n' in 'an'] []
# missing grapheme e
# missing phoneme (overlap) N
# 'ne' in 'ane'
# ane EY N
# ane
# phones ['AE', 'N'] ['N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an'] ['a' in 'ad', 'ne' in 'ane']
# missing grapheme e
# too long
# missing phoneme (overlap) N
# 'ne' in 'ane'
# ane AE N
# ang
# phones ['AE', 'NG'] ['NG', 'AE']
# front & back ['a' in 'ad', ng] ['a' in 'ad', ng]
# yay!
# ang ['a' in 'ad', ng] 2
# ['a' in 'ad', ng] 2
# ['AE', 'NG']
# ang AE NG
# ann
# phones ['AE', 'N'] ['N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an'] ['n' in 'an']
# missing grapheme
# too long
# missing phoneme (overlap) N
# 'n' in 'ann'
# ann AE N
# ano
# phones ['AE', 'N', 'OW'] ['OW', 'N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an', 'o' in 'bo'] ['a' in 'ad', 'n' in 'an', 'o' in 'bo']
# yay!
# ano ['a' in 'ad', 'n' in 'an', 'o' in 'bo'] 3
# ['a' in 'ad', 'n' in 'an', 'o' in 'bo'] 3
# ['AE', 'N', 'OW']
# ano AE N OW
# ano
# too long! ano ['AE', 'N', 'Y', 'OW']
# ano AE N Y OW
# ant
# phones ['AE', 'N', 'T'] ['T', 'N', 'AE']
# front & back ['a' in 'ad', 'n' in 'an', 't' in 'at'] ['a' in 'ad', 'n' in 'an', 't' in 'at']
# yay!
# ant ['a' in 'ad', 'n' in 'an', 't' in 'at'] 3
# ['a' in 'ad', 'n' in 'an', 't' in 'at'] 3
# ['AE', 'N', 'T']
# ant AE N T
# any
# phones ['EH', 'N', 'IY'] ['IY', 'N', 'EH']
# front & back ['a' in 'as', 'n' in 'an', 'y' in 'uy'] ['a' in 'as', 'n' in 'an', 'y' in 'uy']
# yay!
# any ['a' in 'as', 'n' in 'an', 'y' in 'uy'] 3
# ['a' in 'as', 'n' in 'an', 'y' in 'uy'] 3
# ['EH', 'N', 'IY']
# any EH N IY
# aoi
# phones ['AW', 'IY'] ['IY', 'AW']
# front & back [] ['i' in 'di']
# missing grapheme ao
# missing phoneme (clean) AW
# aoi AW IY
# aol
# too long! aol ['EY', 'OW', 'EH', 'L']
# aol EY OW EH L
# aol
# too long! aol ['AH', 'M', 'ER', 'IH', 'K', 'AH', 'AA', 'N', 'L', 'AY', 'N']
# aol AH M ER IH K AH AA N L AY N
# aon
# phones ['EY', 'OW', 'N'] ['N', 'OW', 'EY']
# front & back ['a' in 'ada', 'o' in 'bo', 'n' in 'an'] ['a' in 'ada', 'o' in 'bo', 'n' in 'an']
# yay!
# aon ['a' in 'ada', 'o' in 'bo', 'n' in 'an'] 3
# ['a' in 'ada', 'o' in 'bo', 'n' in 'an'] 3
# ['EY', 'OW', 'N']
# aon EY OW N
# apc
# too long! apc ['EY', 'P', 'IY', 'S', 'IY']
# apc EY P IY S IY
# ape
# phones ['EY', 'P'] ['P', 'EY']
# front & back ['a' in 'ada', 'p' in 'pa'] []
# missing grapheme e
# missing phoneme (overlap) P
# 'pe' in 'ape'
# ape EY P
# api
# too long! api ['EY', 'P', 'IY', 'AY']
# api EY P IY AY
# apo
# too long! apo ['EY', 'P', 'IY', 'OW']
# apo EY P IY OW
# app
# phones ['AE', 'P'] ['P', 'AE']
# front & back ['a' in 'ad', 'p' in 'pa'] ['p' in 'pa']
# missing grapheme
# too long
# missing phoneme (overlap) P
# 'p' in 'app'
# app AE P
# apt
# phones ['AE', 'P', 'T'] ['T', 'P', 'AE']
# front & back ['a' in 'ad', 'p' in 'pa', 't' in 'at'] ['a' in 'ad', 'p' in 'pa', 't' in 'at']
# yay!
# apt ['a' in 'ad', 'p' in 'pa', 't' in 'at'] 3
# ['a' in 'ad', 'p' in 'pa', 't' in 'at'] 3
# ['AE', 'P', 'T']
# apt AE P T
# ara
# phones ['AE', 'R', 'AH'] ['AH', 'R', 'AE']
# front & back ['a' in 'ad', 'r' in 're', 'a' in 'an'] ['a' in 'ad', 'r' in 're', 'a' in 'an']
# yay!
# ara ['a' in 'ad', 'r' in 're', 'a' in 'an'] 3
# ['a' in 'ad', 'r' in 're', 'a' in 'an'] 3
# ['AE', 'R', 'AH']
# ara AE R AH
# arb
# phones ['AA', 'R', 'B'] ['B', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'b' in 'ab'] ['a' in 'ar', 'r' in 're', 'b' in 'ab']
# yay!
# arb ['a' in 'ar', 'r' in 're', 'b' in 'ab'] 3
# ['a' in 'ar', 'r' in 're', 'b' in 'ab'] 3
# ['AA', 'R', 'B']
# arb AA R B
# arc
# phones ['AA', 'R', 'K'] ['K', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'c' in 'ca'] ['a' in 'ar', 'r' in 're', 'c' in 'ca']
# yay!
# arc ['a' in 'ar', 'r' in 're', 'c' in 'ca'] 3
# ['a' in 'ar', 'r' in 're', 'c' in 'ca'] 3
# ['AA', 'R', 'K']
# arc AA R K
# ard
# phones ['AA', 'R', 'D'] ['D', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'd' in 'da'] ['a' in 'ar', 'r' in 're', 'd' in 'da']
# yay!
# ard ['a' in 'ar', 'r' in 're', 'd' in 'da'] 3
# ['a' in 'ar', 'r' in 're', 'd' in 'da'] 3
# ['AA', 'R', 'D']
# ard AA R D
# are
# phones ['AA', 'R'] ['R', 'AA']
# front & back ['a' in 'ar', 'r' in 're'] []
# missing grapheme e
# missing phoneme (overlap) R
# 're' in 'are'
# are AA R
# are
# phones ['ER'] ['ER']
# front & back [] []
# missing grapheme are
# missing phoneme (clean) ER
# are ER
# ari
# phones ['AA', 'R', 'IY'] ['IY', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'i' in 'di'] ['a' in 'ar', 'r' in 're', 'i' in 'di']
# yay!
# ari ['a' in 'ar', 'r' in 're', 'i' in 'di'] 3
# ['a' in 'ar', 'r' in 're', 'i' in 'di'] 3
# ['AA', 'R', 'IY']
# ari AA R IY
# ark
# phones ['AA', 'R', 'K'] ['K', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'k' in 'ka'] ['a' in 'ar', 'r' in 're', 'k' in 'ka']
# yay!
# ark ['a' in 'ar', 'r' in 're', 'k' in 'ka'] 3
# ['a' in 'ar', 'r' in 're', 'k' in 'ka'] 3
# ['AA', 'R', 'K']
# ark AA R K
# arm
# phones ['AA', 'R', 'M'] ['M', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'm' in 'am'] ['a' in 'ar', 'r' in 're', 'm' in 'am']
# yay!
# arm ['a' in 'ar', 'r' in 're', 'm' in 'am'] 3
# ['a' in 'ar', 'r' in 're', 'm' in 'am'] 3
# ['AA', 'R', 'M']
# arm AA R M
# arn
# phones ['AA', 'R', 'N'] ['N', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'n' in 'an'] ['a' in 'ar', 'r' in 're', 'n' in 'an']
# yay!
# arn ['a' in 'ar', 'r' in 're', 'n' in 'an'] 3
# ['a' in 'ar', 'r' in 're', 'n' in 'an'] 3
# ['AA', 'R', 'N']
# arn AA R N
# aro
# phones ['AA', 'R', 'OW'] ['OW', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'o' in 'bo'] ['a' in 'ar', 'r' in 're', 'o' in 'bo']
# yay!
# aro ['a' in 'ar', 'r' in 're', 'o' in 'bo'] 3
# ['a' in 'ar', 'r' in 're', 'o' in 'bo'] 3
# ['AA', 'R', 'OW']
# aro AA R OW
# arp
# phones ['AA', 'R', 'P'] ['P', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 'p' in 'pa'] ['a' in 'ar', 'r' in 're', 'p' in 'pa']
# yay!
# arp ['a' in 'ar', 'r' in 're', 'p' in 'pa'] 3
# ['a' in 'ar', 'r' in 're', 'p' in 'pa'] 3
# ['AA', 'R', 'P']
# arp AA R P
# art
# phones ['AA', 'R', 'T'] ['T', 'R', 'AA']
# front & back ['a' in 'ar', 'r' in 're', 't' in 'at'] ['a' in 'ar', 'r' in 're', 't' in 'at']
# yay!
# art ['a' in 'ar', 'r' in 're', 't' in 'at'] 3
# ['a' in 'ar', 'r' in 're', 't' in 'at'] 3
# ['AA', 'R', 'T']
# art AA R T
# ary
# phones ['EH', 'R', 'IY'] ['IY', 'R', 'EH']
# front & back ['a' in 'as', 'r' in 're', 'y' in 'uy'] ['a' in 'as', 'r' in 're', 'y' in 'uy']
# yay!
# ary ['a' in 'as', 'r' in 're', 'y' in 'uy'] 3
# ['a' in 'as', 'r' in 're', 'y' in 'uy'] 3
# ['EH', 'R', 'IY']
# ary EH R IY
# asa
# phones ['AA', 'S', 'AH'] ['AH', 'S', 'AA']
# front & back ['a' in 'ar', 's' in 'es', 'a' in 'an'] ['a' in 'ar', 's' in 'es', 'a' in 'an']
# yay!
# asa ['a' in 'ar', 's' in 'es', 'a' in 'an'] 3
# ['a' in 'ar', 's' in 'es', 'a' in 'an'] 3
# ['AA', 'S', 'AH']
# asa AA S AH
# ash
# phones ['AE', 'SH'] ['SH', 'AE']
# front & back ['a' in 'ad', sh] ['a' in 'ad', sh]
# yay!
# ash ['a' in 'ad', sh] 2
# ['a' in 'ad', sh] 2
# ['AE', 'SH']
# ash AE SH
# ask
# phones ['AE', 'S', 'K'] ['K', 'S', 'AE']
# front & back ['a' in 'ad', 's' in 'es', 'k' in 'ka'] ['a' in 'ad', 's' in 'es', 'k' in 'ka']
# yay!
# ask ['a' in 'ad', 's' in 'es', 'k' in 'ka'] 3
# ['a' in 'ad', 's' in 'es', 'k' in 'ka'] 3
# ['AE', 'S', 'K']
# ask AE S K
# asp
# phones ['AE', 'S', 'P'] ['P', 'S', 'AE']
# front & back ['a' in 'ad', 's' in 'es', 'p' in 'pa'] ['a' in 'ad', 's' in 'es', 'p' in 'pa']
# yay!
# asp ['a' in 'ad', 's' in 'es', 'p' in 'pa'] 3
# ['a' in 'ad', 's' in 'es', 'p' in 'pa'] 3
# ['AE', 'S', 'P']
# asp AE S P
# ass
# phones ['AE', 'S'] ['S', 'AE']
# front & back ['a' in 'ad', 's' in 'es'] ['s' in 'es']
# missing grapheme
# too long
# missing phoneme (overlap) S
# 's' in 'ass'
# ass AE S
# ast
# phones ['AE', 'S', 'T'] ['T', 'S', 'AE']
# front & back ['a' in 'ad', 's' in 'es', 't' in 'at'] ['a' in 'ad', 's' in 'es', 't' in 'at']
# yay!
# ast ['a' in 'ad', 's' in 'es', 't' in 'at'] 3
# ['a' in 'ad', 's' in 'es', 't' in 'at'] 3
# ['AE', 'S', 'T']
# ast AE S T
# ata
# phones ['AA', 'T', 'AH'] ['AH', 'T', 'AA']
# front & back ['a' in 'ar', 't' in 'at', 'a' in 'an'] ['a' in 'ar', 't' in 'at', 'a' in 'an']
# yay!
# ata ['a' in 'ar', 't' in 'at', 'a' in 'an'] 3
# ['a' in 'ar', 't' in 'at', 'a' in 'an'] 3
# ['AA', 'T', 'AH']
# ata AA T AH
# ate
# phones ['EY', 'T'] ['T', 'EY']
# front & back ['a' in 'ada', 't' in 'at'] []
# missing grapheme e
# missing phoneme (overlap) T
# 'te' in 'ate'
# ate EY T
# ati
# too long! ati ['EY', 'T', 'IY', 'AY']
# ati EY T IY AY
# atm
# too long! atm ['EY', 'T', 'IY', 'EH', 'M']
# atm EY T IY EH M
# atp
# too long! atp ['EY', 'T', 'IY', 'P', 'IY']
# atp EY T IY P IY
# atv
# too long! atv ['EY', 'T', 'IY', 'V', 'IY']
# atv EY T IY V IY
# atz
# phones ['AE', 'T', 'S'] ['S', 'T', 'AE']
# front & back ['a' in 'ad', 't' in 'at'] []
# missing grapheme z
# missing phoneme (clean) S
# atz AE T S
# aud
# phones ['AO', 'D'] ['D', 'AO']
# front & back [] ['d' in 'da']
# missing grapheme au
# missing phoneme (clean) AO
# aud AO D
# aue
# phones ['AW'] ['AW']
# front & back [] []
# missing grapheme aue
# missing phoneme (clean) AW
# aue AW
# aug
# too long! aug ['AO', 'G', 'AH', 'S', 'T']
# aug AO G AH S T
# aul
# phones ['AO', 'L'] ['L', 'AO']
# front & back ['au' in 'aud', 'l' in 'al'] ['au' in 'aud', 'l' in 'al']
# yay!
# aul ['au' in 'aud', 'l' in 'al'] 2
# ['au' in 'aud', 'l' in 'al'] 2
# ['AO', 'L']
# aul AO L
# aus
# phones ['AW', 'Z'] ['Z', 'AW']
# front & back [] ['s' in 'as']
# missing grapheme au
# missing phoneme (clean) AW
# aus AW Z
# ava
# phones ['EY', 'V', 'AH'] ['AH', 'V', 'EY']
# front & back ['a' in 'ada', 'v' in 'vi', 'a' in 'an'] ['a' in 'ada', 'v' in 'vi', 'a' in 'an']
# yay!
# ava ['a' in 'ada', 'v' in 'vi', 'a' in 'an'] 3
# ['a' in 'ada', 'v' in 'vi', 'a' in 'an'] 3
# ['EY', 'V', 'AH']
# ava EY V AH
# ave
# phones ['AA', 'V', 'EY'] ['EY', 'V', 'AA']
# front & back ['a' in 'ar', 'v' in 'vi', 'e' in 'de'] ['a' in 'ar', 'v' in 'vi', 'e' in 'de']
# yay!
# ave ['a' in 'ar', 'v' in 'vi', 'e' in 'de'] 3
# ['a' in 'ar', 'v' in 'vi', 'e' in 'de'] 3
# ['AA', 'V', 'EY']
# ave AA V EY
# avi
# phones ['AA', 'V', 'IY'] ['IY', 'V', 'AA']
# front & back ['a' in 'ar', 'v' in 'vi', 'i' in 'di'] ['a' in 'ar', 'v' in 'vi', 'i' in 'di']
# yay!
# avi ['a' in 'ar', 'v' in 'vi', 'i' in 'di'] 3
# ['a' in 'ar', 'v' in 'vi', 'i' in 'di'] 3
# ['AA', 'V', 'IY']
# avi AA V IY
# avi
# too long! avi ['EY', 'V', 'IY', 'AY']
# avi EY V IY AY
# awb
# phones ['AW', 'B'] ['B', 'AW']
# front & back [] ['b' in 'ab']
# missing grapheme aw
# missing phoneme (clean) AW
# awb AW B
# awb
# too long! awb ['EY', 'D', 'AH', 'B', 'AH', 'L', 'Y', 'UW', 'B', 'IY']
# awb EY D AH B AH L Y UW B IY
# awb
# too long! awb ['EY', 'D', 'AH', 'B', 'AH', 'Y', 'UW', 'B', 'IY']
# awb EY D AH B AH Y UW B IY
# awe
# phones ['AA'] ['AA']
# front & back ['a' in 'ar'] []
# missing grapheme we
# missing phoneme (overlap) AA
# 'awe' in 'awe'
# awe AA
# awe
# phones ['AO'] ['AO']
# front & back ['aw' in 'aw'] []
# missing grapheme e
# missing phoneme (overlap) AO
# 'awe' in 'awe'
# awe AO
# ax
# phones ['AE', 'K', 'S'] ['S', 'K', 'AE']
# front & back ['a' in 'ad', 'k' in 'ka', 's' in 'es'] ['a' in 'ad', 'k' in 'ka', 's' in 'es']
# yay!
# ax ['a' in 'ad', 'k' in 'ka', 's' in 'es'] 3
# ['a' in 'ad', 'k' in 'ka', 's' in 'es'] 3
# ['AE', 'K', 'S']
# ax AE K S
# aye
# phones ['AY'] ['AY']
# front & back ['ay' in 'ay'] []
# missing grapheme e
# missing phoneme (overlap) AY
# 'aye' in 'aye'
# aye AY
# ayn
# phones ['EY', 'N'] ['N', 'EY']
# front & back ['ay' in 'ay', 'n' in 'an'] ['ay' in 'ay', 'n' in 'an']
# yay!
# ayn ['ay' in 'ay', 'n' in 'an'] 2
# ['ay' in 'ay', 'n' in 'an'] 2
# ['EY', 'N']
# ayn EY N
# ayo
# phones ['EY', 'OW'] ['OW', 'EY']
# front & back ['ay' in 'ay', 'o' in 'bo'] ['ay' in 'ay', 'o' in 'bo']
# yay!
# ayo ['ay' in 'ay', 'o' in 'bo'] 2
# ['ay' in 'ay', 'o' in 'bo'] 2
# ['EY', 'OW']
# ayo EY OW
# ayr
# phones ['EY', 'R'] ['R', 'EY']
# front & back ['ay' in 'ay', 'r' in 're'] ['ay' in 'ay', 'r' in 're']
# yay!
# ayr ['ay' in 'ay', 'r' in 're'] 2
# ['ay' in 'ay', 'r' in 're'] 2
# ['EY', 'R']
# ayr EY R
# bad characters b's
# b's B IY Z
# bad characters b-j
# b-j B IY JH EY
# bad characters b.c
# b.c B IY S IY
# bad characters b.s
# b.s B IY Z
# baa
# too long! baa ['B', 'IY', 'EY', 'EY']
# baa B IY EY EY
# bab
# phones ['B', 'AE', 'B'] ['B', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'b' in 'ab'] ['b' in 'ab', 'a' in 'ad', 'b' in 'ab']
# yay!
# bab ['b' in 'ab', 'a' in 'ad', 'b' in 'ab'] 3
# ['b' in 'ab', 'a' in 'ad', 'b' in 'ab'] 3
# ['B', 'AE', 'B']
# bab B AE B
# bad
# phones ['B', 'AE', 'D'] ['D', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'd' in 'da'] ['b' in 'ab', 'a' in 'ad', 'd' in 'da']
# yay!
# bad ['b' in 'ab', 'a' in 'ad', 'd' in 'da'] 3
# ['b' in 'ab', 'a' in 'ad', 'd' in 'da'] 3
# ['B', 'AE', 'D']
# bad B AE D
# bae
# phones ['B', 'AY'] ['AY', 'B']
# front & back ['b' in 'ab'] []
# missing grapheme ae
# missing phoneme (clean) AY
# bae B AY
# bag
# phones ['B', 'AE', 'G'] ['G', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'g' in 'ag'] ['b' in 'ab', 'a' in 'ad', 'g' in 'ag']
# yay!
# bag ['b' in 'ab', 'a' in 'ad', 'g' in 'ag'] 3
# ['b' in 'ab', 'a' in 'ad', 'g' in 'ag'] 3
# ['B', 'AE', 'G']
# bag B AE G
# bah
# phones ['B', 'AA'] ['AA', 'B']
# front & back ['b' in 'ab', 'ah' in 'ah'] ['b' in 'ab', 'ah' in 'ah']
# yay!
# bah ['b' in 'ab', 'ah' in 'ah'] 2
# ['b' in 'ab', 'ah' in 'ah'] 2
# ['B', 'AA']
# bah B AA
# bak
# phones ['B', 'AE', 'K'] ['K', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'k' in 'ka'] ['b' in 'ab', 'a' in 'ad', 'k' in 'ka']
# yay!
# bak ['b' in 'ab', 'a' in 'ad', 'k' in 'ka'] 3
# ['b' in 'ab', 'a' in 'ad', 'k' in 'ka'] 3
# ['B', 'AE', 'K']
# bak B AE K
# bal
# phones ['B', 'AE', 'L'] ['L', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'l' in 'al'] ['b' in 'ab', 'a' in 'ad', 'l' in 'al']
# yay!
# bal ['b' in 'ab', 'a' in 'ad', 'l' in 'al'] 3
# ['b' in 'ab', 'a' in 'ad', 'l' in 'al'] 3
# ['B', 'AE', 'L']
# bal B AE L
# bam
# phones ['B', 'AE', 'M'] ['M', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'm' in 'am'] ['b' in 'ab', 'a' in 'ad', 'm' in 'am']
# yay!
# bam ['b' in 'ab', 'a' in 'ad', 'm' in 'am'] 3
# ['b' in 'ab', 'a' in 'ad', 'm' in 'am'] 3
# ['B', 'AE', 'M']
# bam B AE M
# ban
# phones ['B', 'AE', 'N'] ['N', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'n' in 'an'] ['b' in 'ab', 'a' in 'ad', 'n' in 'an']
# yay!
# ban ['b' in 'ab', 'a' in 'ad', 'n' in 'an'] 3
# ['b' in 'ab', 'a' in 'ad', 'n' in 'an'] 3
# ['B', 'AE', 'N']
# ban B AE N
# bao
# phones ['B', 'AW'] ['AW', 'B']
# front & back ['b' in 'ab', 'ao' in 'aoi'] ['b' in 'ab', 'ao' in 'aoi']
# yay!
# bao ['b' in 'ab', 'ao' in 'aoi'] 2
# ['b' in 'ab', 'ao' in 'aoi'] 2
# ['B', 'AW']
# bao B AW
# bar
# phones ['B', 'AA', 'R'] ['R', 'AA', 'B']
# front & back ['b' in 'ab', 'a' in 'ar', 'r' in 're'] ['b' in 'ab', 'a' in 'ar', 'r' in 're']
# yay!
# bar ['b' in 'ab', 'a' in 'ar', 'r' in 're'] 3
# ['b' in 'ab', 'a' in 'ar', 'r' in 're'] 3
# ['B', 'AA', 'R']
# bar B AA R
# bat
# phones ['B', 'AE', 'T'] ['T', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 't' in 'at'] ['b' in 'ab', 'a' in 'ad', 't' in 'at']
# yay!
# bat ['b' in 'ab', 'a' in 'ad', 't' in 'at'] 3
# ['b' in 'ab', 'a' in 'ad', 't' in 'at'] 3
# ['B', 'AE', 'T']
# bat B AE T
# bay
# phones ['B', 'EY'] ['EY', 'B']
# front & back ['b' in 'ab', 'ay' in 'ay'] ['b' in 'ab', 'ay' in 'ay']
# yay!
# bay ['b' in 'ab', 'ay' in 'ay'] 2
# ['b' in 'ab', 'ay' in 'ay'] 2
# ['B', 'EY']
# bay B EY
# baz
# phones ['B', 'AE', 'Z'] ['Z', 'AE', 'B']
# front & back ['b' in 'ab', 'a' in 'ad', 'z' in 'oz'] ['b' in 'ab', 'a' in 'ad', 'z' in 'oz']
# yay!
# baz ['b' in 'ab', 'a' in 'ad', 'z' in 'oz'] 3
# ['b' in 'ab', 'a' in 'ad', 'z' in 'oz'] 3
# ['B', 'AE', 'Z']
# baz B AE Z
# bbq
# too long! bbq ['B', 'AA', 'R', 'B', 'IH', 'K', 'Y', 'UW']
# bbq B AA R B IH K Y UW
# bea
# phones ['B', 'IY'] ['IY', 'B']
# front & back ['b' in 'ab', ea] ['b' in 'ab', ea]
# yay!
# bea ['b' in 'ab', ea] 2
# ['b' in 'ab', ea] 2
# ['B', 'IY']
# bea B IY
# bec
# phones ['B', 'EH', 'K'] ['K', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'c' in 'ca'] ['b' in 'ab', 'e' in 'eb', 'c' in 'ca']
# yay!
# bec ['b' in 'ab', 'e' in 'eb', 'c' in 'ca'] 3
# ['b' in 'ab', 'e' in 'eb', 'c' in 'ca'] 3
# ['B', 'EH', 'K']
# bec B EH K
# bed
# phones ['B', 'EH', 'D'] ['D', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'd' in 'da'] ['b' in 'ab', 'e' in 'eb', 'd' in 'da']
# yay!
# bed ['b' in 'ab', 'e' in 'eb', 'd' in 'da'] 3
# ['b' in 'ab', 'e' in 'eb', 'd' in 'da'] 3
# ['B', 'EH', 'D']
# bed B EH D
# bee
# phones ['B', 'IY'] ['IY', 'B']
# front & back ['b' in 'ab', 'e' in 'be'] ['e' in 'be']
# missing grapheme
# too long
# missing phoneme (overlap) IY
# 'e' in 'bee'
# bee B IY
# beg
# phones ['B', 'EH', 'G'] ['G', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'g' in 'ag'] ['b' in 'ab', 'e' in 'eb', 'g' in 'ag']
# yay!
# beg ['b' in 'ab', 'e' in 'eb', 'g' in 'ag'] 3
# ['b' in 'ab', 'e' in 'eb', 'g' in 'ag'] 3
# ['B', 'EH', 'G']
# beg B EH G
# bel
# phones ['B', 'EH', 'L'] ['L', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'l' in 'al'] ['b' in 'ab', 'e' in 'eb', 'l' in 'al']
# yay!
# bel ['b' in 'ab', 'e' in 'eb', 'l' in 'al'] 3
# ['b' in 'ab', 'e' in 'eb', 'l' in 'al'] 3
# ['B', 'EH', 'L']
# bel B EH L
# bem
# phones ['B', 'EH', 'M'] ['M', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'm' in 'am'] ['b' in 'ab', 'e' in 'eb', 'm' in 'am']
# yay!
# bem ['b' in 'ab', 'e' in 'eb', 'm' in 'am'] 3
# ['b' in 'ab', 'e' in 'eb', 'm' in 'am'] 3
# ['B', 'EH', 'M']
# bem B EH M
# ben
# phones ['B', 'EH', 'N'] ['N', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'n' in 'an'] ['b' in 'ab', 'e' in 'eb', 'n' in 'an']
# yay!
# ben ['b' in 'ab', 'e' in 'eb', 'n' in 'an'] 3
# ['b' in 'ab', 'e' in 'eb', 'n' in 'an'] 3
# ['B', 'EH', 'N']
# ben B EH N
# bes
# phones ['B', 'IY', 'Z'] ['Z', 'IY', 'B']
# front & back ['b' in 'ab', 'e' in 'be', 's' in 'as'] ['b' in 'ab', 'e' in 'be', 's' in 'as']
# yay!
# bes ['b' in 'ab', 'e' in 'be', 's' in 'as'] 3
# ['b' in 'ab', 'e' in 'be', 's' in 'as'] 3
# ['B', 'IY', 'Z']
# bes B IY Z
# bet
# phones ['B', 'EH', 'T'] ['T', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 't' in 'at'] ['b' in 'ab', 'e' in 'eb', 't' in 'at']
# yay!
# bet ['b' in 'ab', 'e' in 'eb', 't' in 'at'] 3
# ['b' in 'ab', 'e' in 'eb', 't' in 'at'] 3
# ['B', 'EH', 'T']
# bet B EH T
# beu
# phones ['B', 'UW'] ['UW', 'B']
# front & back ['b' in 'ab'] ['u' in 'du']
# missing grapheme e
# missing phoneme (overlap) B
# 'be' in 'beu'
# beu B UW
# bev
# phones ['B', 'EH', 'V'] ['V', 'EH', 'B']
# front & back ['b' in 'ab', 'e' in 'eb', 'v' in 'vi'] ['b' in 'ab', 'e' in 'eb', 'v' in 'vi']
# yay!
# bev ['b' in 'ab', 'e' in 'eb', 'v' in 'vi'] 3
# ['b' in 'ab', 'e' in 'eb', 'v' in 'vi'] 3
# ['B', 'EH', 'V']
# bev B EH V
# bey
# phones ['B', 'EY'] ['EY', 'B']
# front & back ['b' in 'ab', 'e' in 'de'] ['be' in 'beu', 'y' in 'wy']
# missing grapheme y
# too long
# missing phoneme (overlap) EY
# 'ey' in 'bey'
# bey B EY
# bib
# phones ['B', 'IH', 'B'] ['B', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'b' in 'ab'] ['b' in 'ab', 'i' in 'if', 'b' in 'ab']
# yay!
# bib ['b' in 'ab', 'i' in 'if', 'b' in 'ab'] 3
# ['b' in 'ab', 'i' in 'if', 'b' in 'ab'] 3
# ['B', 'IH', 'B']
# bib B IH B
# bic
# phones ['B', 'IH', 'K'] ['K', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'c' in 'ca'] ['b' in 'ab', 'i' in 'if', 'c' in 'ca']
# yay!
# bic ['b' in 'ab', 'i' in 'if', 'c' in 'ca'] 3
# ['b' in 'ab', 'i' in 'if', 'c' in 'ca'] 3
# ['B', 'IH', 'K']
# bic B IH K
# bid
# phones ['B', 'IH', 'D'] ['D', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'd' in 'da'] ['b' in 'ab', 'i' in 'if', 'd' in 'da']
# yay!
# bid ['b' in 'ab', 'i' in 'if', 'd' in 'da'] 3
# ['b' in 'ab', 'i' in 'if', 'd' in 'da'] 3
# ['B', 'IH', 'D']
# bid B IH D
# big
# phones ['B', 'IH', 'G'] ['G', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'g' in 'ag'] ['b' in 'ab', 'i' in 'if', 'g' in 'ag']
# yay!
# big ['b' in 'ab', 'i' in 'if', 'g' in 'ag'] 3
# ['b' in 'ab', 'i' in 'if', 'g' in 'ag'] 3
# ['B', 'IH', 'G']
# big B IH G
# bil
# phones ['B', 'IH', 'L'] ['L', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'l' in 'al'] ['b' in 'ab', 'i' in 'if', 'l' in 'al']
# yay!
# bil ['b' in 'ab', 'i' in 'if', 'l' in 'al'] 3
# ['b' in 'ab', 'i' in 'if', 'l' in 'al'] 3
# ['B', 'IH', 'L']
# bil B IH L
# bin
# phones ['B', 'IH', 'N'] ['N', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'n' in 'an'] ['b' in 'ab', 'i' in 'if', 'n' in 'an']
# yay!
# bin ['b' in 'ab', 'i' in 'if', 'n' in 'an'] 3
# ['b' in 'ab', 'i' in 'if', 'n' in 'an'] 3
# ['B', 'IH', 'N']
# bin B IH N
# bio
# phones ['B', 'AY', 'OW'] ['OW', 'AY', 'B']
# front & back ['b' in 'ab', 'i' in 'fi', 'o' in 'bo'] ['b' in 'ab', 'i' in 'fi', 'o' in 'bo']
# yay!
# bio ['b' in 'ab', 'i' in 'fi', 'o' in 'bo'] 3
# ['b' in 'ab', 'i' in 'fi', 'o' in 'bo'] 3
# ['B', 'AY', 'OW']
# bio B AY OW
# bip
# phones ['B', 'IH', 'P'] ['P', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'p' in 'pa'] ['b' in 'ab', 'i' in 'if', 'p' in 'pa']
# yay!
# bip ['b' in 'ab', 'i' in 'if', 'p' in 'pa'] 3
# ['b' in 'ab', 'i' in 'if', 'p' in 'pa'] 3
# ['B', 'IH', 'P']
# bip B IH P
# bir
# phones ['B', 'ER'] ['ER', 'B']
# front & back ['b' in 'ab', ir] ['b' in 'ab', ir]
# yay!
# bir ['b' in 'ab', ir] 2
# ['b' in 'ab', ir] 2
# ['B', 'ER']
# bir B ER
# bis
# phones ['B', 'IH', 'S'] ['S', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 's' in 'es'] ['b' in 'ab', 'i' in 'if', 's' in 'es']
# yay!
# bis ['b' in 'ab', 'i' in 'if', 's' in 'es'] 3
# ['b' in 'ab', 'i' in 'if', 's' in 'es'] 3
# ['B', 'IH', 'S']
# bis B IH S
# bit
# phones ['B', 'IH', 'T'] ['T', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 't' in 'at'] ['b' in 'ab', 'i' in 'if', 't' in 'at']
# yay!
# bit ['b' in 'ab', 'i' in 'if', 't' in 'at'] 3
# ['b' in 'ab', 'i' in 'if', 't' in 'at'] 3
# ['B', 'IH', 'T']
# bit B IH T
# biz
# phones ['B', 'IH', 'Z'] ['Z', 'IH', 'B']
# front & back ['b' in 'ab', 'i' in 'if', 'z' in 'oz'] ['b' in 'ab', 'i' in 'if', 'z' in 'oz']
# yay!
# biz ['b' in 'ab', 'i' in 'if', 'z' in 'oz'] 3
# ['b' in 'ab', 'i' in 'if', 'z' in 'oz'] 3
# ['B', 'IH', 'Z']
# biz B IH Z
# bly
# phones ['B', 'L', 'AY'] ['AY', 'L', 'B']
# front & back ['b' in 'ab', 'l' in 'al', 'y' in 'by'] ['b' in 'ab', 'l' in 'al', 'y' in 'by']
# yay!
# bly ['b' in 'ab', 'l' in 'al', 'y' in 'by'] 3
# ['b' in 'ab', 'l' in 'al', 'y' in 'by'] 3
# ['B', 'L', 'AY']
# bly B L AY
# boa
# phones ['B', 'OW', 'AH'] ['AH', 'OW', 'B']
# front & back ['b' in 'ab', oa] ['b' in 'ab', 'o' in 'bo', 'a' in 'an']
# missing grapheme
# too long
# missing phoneme (overlap) OW
# 'oa' in 'boa'
# boa B OW AH
# bob
# phones ['B', 'AA', 'B'] ['B', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'b' in 'ab'] ['b' in 'ab', 'o' in 'og', 'b' in 'ab']
# yay!
# bob ['b' in 'ab', 'o' in 'og', 'b' in 'ab'] 3
# ['b' in 'ab', 'o' in 'og', 'b' in 'ab'] 3
# ['B', 'AA', 'B']
# bob B AA B
# boe
# phones ['B', 'OW'] ['OW', 'B']
# front & back ['b' in 'ab', 'o' in 'bo'] []
# missing grapheme e
# missing phoneme (overlap) OW
# 'oe' in 'boe'
# boe B OW
# bog
# phones ['B', 'AA', 'G'] ['G', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'g' in 'ag'] ['b' in 'ab', 'o' in 'og', 'g' in 'ag']
# yay!
# bog ['b' in 'ab', 'o' in 'og', 'g' in 'ag'] 3
# ['b' in 'ab', 'o' in 'og', 'g' in 'ag'] 3
# ['B', 'AA', 'G']
# bog B AA G
# bog
# phones ['B', 'AO', 'G'] ['G', 'AO', 'B']
# front & back ['b' in 'ab', 'o' in 'om', 'g' in 'ag'] ['b' in 'ab', 'o' in 'om', 'g' in 'ag']
# yay!
# bog ['b' in 'ab', 'o' in 'om', 'g' in 'ag'] 3
# ['b' in 'ab', 'o' in 'om', 'g' in 'ag'] 3
# ['B', 'AO', 'G']
# bog B AO G
# bok
# phones ['B', 'AA', 'K'] ['K', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'k' in 'ka'] ['b' in 'ab', 'o' in 'og', 'k' in 'ka']
# yay!
# bok ['b' in 'ab', 'o' in 'og', 'k' in 'ka'] 3
# ['b' in 'ab', 'o' in 'og', 'k' in 'ka'] 3
# ['B', 'AA', 'K']
# bok B AA K
# bol
# phones ['B', 'AA', 'L'] ['L', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'l' in 'al'] ['b' in 'ab', 'o' in 'og', 'l' in 'al']
# yay!
# bol ['b' in 'ab', 'o' in 'og', 'l' in 'al'] 3
# ['b' in 'ab', 'o' in 'og', 'l' in 'al'] 3
# ['B', 'AA', 'L']
# bol B AA L
# bom
# phones ['B', 'AA', 'M'] ['M', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'm' in 'am'] ['b' in 'ab', 'o' in 'og', 'm' in 'am']
# yay!
# bom ['b' in 'ab', 'o' in 'og', 'm' in 'am'] 3
# ['b' in 'ab', 'o' in 'og', 'm' in 'am'] 3
# ['B', 'AA', 'M']
# bom B AA M
# bon
# phones ['B', 'AA', 'N'] ['N', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'n' in 'an'] ['b' in 'ab', 'o' in 'og', 'n' in 'an']
# yay!
# bon ['b' in 'ab', 'o' in 'og', 'n' in 'an'] 3
# ['b' in 'ab', 'o' in 'og', 'n' in 'an'] 3
# ['B', 'AA', 'N']
# bon B AA N
# boo
# phones ['B', 'UW'] ['UW', 'B']
# front & back ['b' in 'ab', oo] ['b' in 'ab', oo]
# yay!
# boo ['b' in 'ab', oo] 2
# ['b' in 'ab', oo] 2
# ['B', 'UW']
# boo B UW
# bop
# phones ['B', 'AA', 'P'] ['P', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 'p' in 'pa'] ['b' in 'ab', 'o' in 'og', 'p' in 'pa']
# yay!
# bop ['b' in 'ab', 'o' in 'og', 'p' in 'pa'] 3
# ['b' in 'ab', 'o' in 'og', 'p' in 'pa'] 3
# ['B', 'AA', 'P']
# bop B AA P
# bos
# phones ['B', 'AA', 'S'] ['S', 'AA', 'B']
# front & back ['b' in 'ab', 'o' in 'og', 's' in 'es'] ['b' in 'ab', 'o' in 'og', 's' in 'es']
# yay!
# bos ['b' in 'ab', 'o' in 'og', 's' in 'es'] 3
# ['b' in 'ab', 'o' in 'og', 's' in 'es'] 3
# ['B', 'AA', 'S']
# bos B AA S
# bot
# phones ['B', 'AO', 'T'] ['T', 'AO', 'B']
# front & back ['b' in 'ab', 'o' in 'om', 't' in 'at'] ['b' in 'ab', 'o' in 'om', 't' in 'at']
# yay!
# bot ['b' in 'ab', 'o' in 'om', 't' in 'at'] 3
# ['b' in 'ab', 'o' in 'om', 't' in 'at'] 3
# ['B', 'AO', 'T']
# bot B AO T
# bow
# phones ['B', 'AW'] ['AW', 'B']
# front & back ['b' in 'ab', 'ow' in 'ow'] ['b' in 'ab', 'ow' in 'ow']
# yay!
# bow ['b' in 'ab', 'ow' in 'ow'] 2
# ['b' in 'ab', 'ow' in 'ow'] 2
# ['B', 'AW']
# bow B AW
# bow
# phones ['B', 'OW'] ['OW', 'B']
# front & back ['b' in 'ab', 'o' in 'bo'] ['b' in 'ab', 'ow' in 'ow']
# missing grapheme w
# too long
# missing phoneme (overlap) OW
# 'ow' in 'bow'
# bow B OW
# boy
# phones ['B', 'OY'] ['OY', 'B']
# front & back ['b' in 'ab', 'oy' in 'oy'] ['b' in 'ab', 'oy' in 'oy']
# yay!
# boy ['b' in 'ab', 'oy' in 'oy'] 2
# ['b' in 'ab', 'oy' in 'oy'] 2
# ['B', 'OY']
# boy B OY
# bra
# phones ['B', 'R', 'AA'] ['AA', 'R', 'B']
# front & back ['b' in 'ab', 'r' in 're', 'a' in 'ar'] ['b' in 'ab', 'r' in 're', 'a' in 'ar']
# yay!
# bra ['b' in 'ab', 'r' in 're', 'a' in 'ar'] 3
# ['b' in 'ab', 'r' in 're', 'a' in 'ar'] 3
# ['B', 'R', 'AA']
# bra B R AA
# bro
# phones ['B', 'R', 'OW'] ['OW', 'R', 'B']
# front & back ['b' in 'ab', 'r' in 're', 'o' in 'bo'] ['b' in 'ab', 'r' in 're', 'o' in 'bo']
# yay!
# bro ['b' in 'ab', 'r' in 're', 'o' in 'bo'] 3
# ['b' in 'ab', 'r' in 're', 'o' in 'bo'] 3
# ['B', 'R', 'OW']
# bro B R OW
# bta
# too long! bta ['B', 'IY', 'T', 'IY', 'EY']
# bta B IY T IY EY
# bua
# too long! bua ['B', 'Y', 'UW', 'AH']
# bua B Y UW AH
# bua
# too long! bua ['B', 'IY', 'Y', 'UW', 'EY']
# bua B IY Y UW EY
# bub
# phones ['B', 'AH', 'B'] ['B', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'b' in 'ab'] ['b' in 'ab', 'u' in 'um', 'b' in 'ab']
# yay!
# bub ['b' in 'ab', 'u' in 'um', 'b' in 'ab'] 3
# ['b' in 'ab', 'u' in 'um', 'b' in 'ab'] 3
# ['B', 'AH', 'B']
# bub B AH B
# buc
# phones ['B', 'AH', 'K'] ['K', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'c' in 'ca'] ['b' in 'ab', 'u' in 'um', 'c' in 'ca']
# yay!
# buc ['b' in 'ab', 'u' in 'um', 'c' in 'ca'] 3
# ['b' in 'ab', 'u' in 'um', 'c' in 'ca'] 3
# ['B', 'AH', 'K']
# buc B AH K
# bud
# phones ['B', 'AH', 'D'] ['D', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'd' in 'da'] ['b' in 'ab', 'u' in 'um', 'd' in 'da']
# yay!
# bud ['b' in 'ab', 'u' in 'um', 'd' in 'da'] 3
# ['b' in 'ab', 'u' in 'um', 'd' in 'da'] 3
# ['B', 'AH', 'D']
# bud B AH D
# bue
# phones ['B', 'W', 'EH'] ['EH', 'W', 'B']
# front & back ['b' in 'ab'] ['e' in 'eb']
# missing grapheme u
# missing phoneme (clean) W
# bue B W EH
# bug
# phones ['B', 'AH', 'G'] ['G', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'g' in 'ag'] ['b' in 'ab', 'u' in 'um', 'g' in 'ag']
# yay!
# bug ['b' in 'ab', 'u' in 'um', 'g' in 'ag'] 3
# ['b' in 'ab', 'u' in 'um', 'g' in 'ag'] 3
# ['B', 'AH', 'G']
# bug B AH G
# bui
# phones ['B', 'IH'] ['IH', 'B']
# front & back ['b' in 'ab'] ['i' in 'if']
# missing grapheme u
# missing phoneme (overlap) B
# 'bu' in 'bui'
# bui B IH
# bui
# phones ['B', 'W', 'IY'] ['IY', 'W', 'B']
# front & back ['b' in 'ab', 'u' in 'bue', 'i' in 'di'] ['b' in 'ab', 'u' in 'bue', 'i' in 'di']
# yay!
# bui ['b' in 'ab', 'u' in 'bue', 'i' in 'di'] 3
# ['b' in 'ab', 'u' in 'bue', 'i' in 'di'] 3
# ['B', 'W', 'IY']
# bui B W IY
# bum
# phones ['B', 'AH', 'M'] ['M', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'm' in 'am'] ['b' in 'ab', 'u' in 'um', 'm' in 'am']
# yay!
# bum ['b' in 'ab', 'u' in 'um', 'm' in 'am'] 3
# ['b' in 'ab', 'u' in 'um', 'm' in 'am'] 3
# ['B', 'AH', 'M']
# bum B AH M
# bun
# phones ['B', 'AH', 'N'] ['N', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 'n' in 'an'] ['b' in 'ab', 'u' in 'um', 'n' in 'an']
# yay!
# bun ['b' in 'ab', 'u' in 'um', 'n' in 'an'] 3
# ['b' in 'ab', 'u' in 'um', 'n' in 'an'] 3
# ['B', 'AH', 'N']
# bun B AH N
# bur
# phones ['B', 'ER'] ['ER', 'B']
# front & back ['b' in 'ab', 'ur' in 'ur'] ['b' in 'ab', 'ur' in 'ur']
# yay!
# bur ['b' in 'ab', 'ur' in 'ur'] 2
# ['b' in 'ab', 'ur' in 'ur'] 2
# ['B', 'ER']
# bur B ER
# bus
# phones ['B', 'AH', 'S'] ['S', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 's' in 'es'] ['b' in 'ab', 'u' in 'um', 's' in 'es']
# yay!
# bus ['b' in 'ab', 'u' in 'um', 's' in 'es'] 3
# ['b' in 'ab', 'u' in 'um', 's' in 'es'] 3
# ['B', 'AH', 'S']
# bus B AH S
# but
# phones ['B', 'AH', 'T'] ['T', 'AH', 'B']
# front & back ['b' in 'ab', 'u' in 'um', 't' in 'at'] ['b' in 'ab', 'u' in 'um', 't' in 'at']
# yay!
# but ['b' in 'ab', 'u' in 'um', 't' in 'at'] 3
# ['b' in 'ab', 'u' in 'um', 't' in 'at'] 3
# ['B', 'AH', 'T']
# but B AH T
# buy
# phones ['B', 'AY'] ['AY', 'B']
# front & back ['b' in 'ab'] ['bu' in 'bui', 'y' in 'by']
# missing grapheme uy
# too long
# missing phoneme (overlap) B
# 'buy' in 'buy'
# buy B AY
# bye
# phones ['B', 'AY'] ['AY', 'B']
# front & back ['b' in 'ab', 'y' in 'by'] []
# missing grapheme e
# missing phoneme (overlap) AY
# 'ye' in 'bye'
# bye B AY
# bad characters c's
# c's S IY Z
# bad characters c.s
# c.s S IY Z
# cab
# phones ['K', 'AE', 'B'] ['B', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'b' in 'ab'] ['c' in 'ca', 'a' in 'ad', 'b' in 'ab']
# yay!
# cab ['c' in 'ca', 'a' in 'ad', 'b' in 'ab'] 3
# ['c' in 'ca', 'a' in 'ad', 'b' in 'ab'] 3
# ['K', 'AE', 'B']
# cab K AE B
# cac
# phones ['K', 'AE', 'K'] ['K', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'c' in 'ca'] ['c' in 'ca', 'a' in 'ad', 'c' in 'ca']
# yay!
# cac ['c' in 'ca', 'a' in 'ad', 'c' in 'ca'] 3
# ['c' in 'ca', 'a' in 'ad', 'c' in 'ca'] 3
# ['K', 'AE', 'K']
# cac K AE K
# cac
# too long! cac ['S', 'IY', 'EY', 'S', 'IY']
# cac S IY EY S IY
# cad
# phones ['K', 'AE', 'D'] ['D', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'd' in 'da'] ['c' in 'ca', 'a' in 'ad', 'd' in 'da']
# yay!
# cad ['c' in 'ca', 'a' in 'ad', 'd' in 'da'] 3
# ['c' in 'ca', 'a' in 'ad', 'd' in 'da'] 3
# ['K', 'AE', 'D']
# cad K AE D
# cai
# phones ['K', 'AY'] ['AY', 'K']
# front & back ['c' in 'ca', 'ai' in 'ai'] ['i' in 'fi']
# missing grapheme
# too long
# missing phoneme (overlap) AY
# 'ai' in 'cai'
# cai K AY
# cal
# phones ['K', 'AE', 'L'] ['L', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'l' in 'al'] ['c' in 'ca', 'a' in 'ad', 'l' in 'al']
# yay!
# cal ['c' in 'ca', 'a' in 'ad', 'l' in 'al'] 3
# ['c' in 'ca', 'a' in 'ad', 'l' in 'al'] 3
# ['K', 'AE', 'L']
# cal K AE L
# cam
# phones ['K', 'AE', 'M'] ['M', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'm' in 'am'] ['c' in 'ca', 'a' in 'ad', 'm' in 'am']
# yay!
# cam ['c' in 'ca', 'a' in 'ad', 'm' in 'am'] 3
# ['c' in 'ca', 'a' in 'ad', 'm' in 'am'] 3
# ['K', 'AE', 'M']
# cam K AE M
# can
# phones ['K', 'AE', 'N'] ['N', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'n' in 'an'] ['c' in 'ca', 'a' in 'ad', 'n' in 'an']
# yay!
# can ['c' in 'ca', 'a' in 'ad', 'n' in 'an'] 3
# ['c' in 'ca', 'a' in 'ad', 'n' in 'an'] 3
# ['K', 'AE', 'N']
# can K AE N
# can
# phones ['K', 'AH', 'N'] ['N', 'AH', 'K']
# front & back ['c' in 'ca', 'a' in 'an', 'n' in 'an'] ['c' in 'ca', 'a' in 'an', 'n' in 'an']
# yay!
# can ['c' in 'ca', 'a' in 'an', 'n' in 'an'] 3
# ['c' in 'ca', 'a' in 'an', 'n' in 'an'] 3
# ['K', 'AH', 'N']
# can K AH N
# cao
# phones ['K', 'AW'] ['AW', 'K']
# front & back ['c' in 'ca', 'ao' in 'aoi'] ['c' in 'ca', 'ao' in 'aoi']
# yay!
# cao ['c' in 'ca', 'ao' in 'aoi'] 2
# ['c' in 'ca', 'ao' in 'aoi'] 2
# ['K', 'AW']
# cao K AW
# cap
# phones ['K', 'AE', 'P'] ['P', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'p' in 'pa'] ['c' in 'ca', 'a' in 'ad', 'p' in 'pa']
# yay!
# cap ['c' in 'ca', 'a' in 'ad', 'p' in 'pa'] 3
# ['c' in 'ca', 'a' in 'ad', 'p' in 'pa'] 3
# ['K', 'AE', 'P']
# cap K AE P
# caq
# phones ['K', 'AE', 'K'] ['K', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 'q' in 'qi'] ['c' in 'ca', 'a' in 'ad', 'q' in 'qi']
# yay!
# caq ['c' in 'ca', 'a' in 'ad', 'q' in 'qi'] 3
# ['c' in 'ca', 'a' in 'ad', 'q' in 'qi'] 3
# ['K', 'AE', 'K']
# caq K AE K
# car
# phones ['K', 'AA', 'R'] ['R', 'AA', 'K']
# front & back ['c' in 'ca', 'a' in 'ar', 'r' in 're'] ['c' in 'ca', 'a' in 'ar', 'r' in 're']
# yay!
# car ['c' in 'ca', 'a' in 'ar', 'r' in 're'] 3
# ['c' in 'ca', 'a' in 'ar', 'r' in 're'] 3
# ['K', 'AA', 'R']
# car K AA R
# cas
# phones ['K', 'AE', 'S'] ['S', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 's' in 'es'] ['c' in 'ca', 'a' in 'ad', 's' in 'es']
# yay!
# cas ['c' in 'ca', 'a' in 'ad', 's' in 'es'] 3
# ['c' in 'ca', 'a' in 'ad', 's' in 'es'] 3
# ['K', 'AE', 'S']
# cas K AE S
# cat
# phones ['K', 'AE', 'T'] ['T', 'AE', 'K']
# front & back ['c' in 'ca', 'a' in 'ad', 't' in 'at'] ['c' in 'ca', 'a' in 'ad', 't' in 'at']
# yay!
# cat ['c' in 'ca', 'a' in 'ad', 't' in 'at'] 3
# ['c' in 'ca', 'a' in 'ad', 't' in 'at'] 3
# ['K', 'AE', 'T']
# cat K AE T
# cat
# too long! cat ['K', 'AE', 'T', 'W', 'AO', 'N']
# cat K AE T W AO N
# cat
# too long! cat ['K', 'AE', 'T', 'T', 'UW']
# cat K AE T T UW
# cat
# too long! cat ['K', 'AE', 'T', 'TH', 'R', 'IY']
# cat K AE T TH R IY
# cat
# too long! cat ['K', 'AE', 'T', 'F', 'AO', 'R']
# cat K AE T F AO R
# cat
# too long! cat ['K', 'AE', 'T', 'S', 'IH', 'K', 'S']
# cat K AE T S IH K S
# cau
# phones ['K', 'AW'] ['AW', 'K']
# front & back ['c' in 'ca', 'au' in 'aus'] ['c' in 'ca', 'au' in 'aus']
# yay!
# cau ['c' in 'ca', 'au' in 'aus'] 2
# ['c' in 'ca', 'au' in 'aus'] 2
# ['K', 'AW']
# cau K AW
# cau
# phones ['K', 'OW'] ['OW', 'K']
# ...
# front & back [] ['i' in 'fi', 'n' in 'an']
# missing grapheme e
# missing phoneme (overlap) N
# 'ei' in 'ein'
# ein AY N
# eir
# phones ['AY', 'R'] ['R', 'AY']
# front & back [] ['i' in 'fi', 'r' in 're']
# missing grapheme e
# missing phoneme (overlap) R
# 'ei' in 'eir'
# eir AY R
# eis
# phones ['AY', 'Z'] ['Z', 'AY']
# front & back [] ['i' in 'fi', 's' in 'as']
# missing grapheme e
# missing phoneme (overlap) Z
# 'ei' in 'eis'
# eis AY Z
# eka
# phones ['EH', 'K', 'AH'] ['AH', 'K', 'EH']
# front & back ['e' in 'eb', 'k' in 'ka', 'a' in 'an'] ['e' in 'eb', 'k' in 'ka', 'a' in 'an']
# yay!
# eka ['e' in 'eb', 'k' in 'ka', 'a' in 'an'] 3
# ['e' in 'eb', 'k' in 'ka', 'a' in 'an'] 3
# ['EH', 'K', 'AH']
# eka EH K AH
# eke
# phones ['IY', 'K'] ['K', 'IY']
# front & back ['e' in 'be', 'k' in 'ka'] ['e' in 'be', 'ke' in 'ake']
# missing grapheme e
# too long
# missing phoneme (overlap) K
# 'ke' in 'eke'
# eke IY K
# ekk
# too long! ekk ['IY', 'K', 'EY', 'K', 'EY']
# ekk IY K EY K EY
# eko
# phones ['EH', 'K', 'OW'] ['OW', 'K', 'EH']
# front & back ['e' in 'eb', 'k' in 'ka', 'o' in 'bo'] ['e' in 'eb', 'k' in 'ka', 'o' in 'bo']
# yay!
# eko ['e' in 'eb', 'k' in 'ka', 'o' in 'bo'] 3
# ['e' in 'eb', 'k' in 'ka', 'o' in 'bo'] 3
# ['EH', 'K', 'OW']
# eko EH K OW
# ela
# phones ['EH', 'L', 'AH'] ['AH', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 'a' in 'an'] ['e' in 'eb', 'l' in 'al', 'a' in 'an']
# yay!
# ela ['e' in 'eb', 'l' in 'al', 'a' in 'an'] 3
# ['e' in 'eb', 'l' in 'al', 'a' in 'an'] 3
# ['EH', 'L', 'AH']
# ela EH L AH
# elf
# phones ['EH', 'L', 'F'] ['F', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 'f' in 'fe'] ['e' in 'eb', 'l' in 'al', 'f' in 'fe']
# yay!
# elf ['e' in 'eb', 'l' in 'al', 'f' in 'fe'] 3
# ['e' in 'eb', 'l' in 'al', 'f' in 'fe'] 3
# ['EH', 'L', 'F']
# elf EH L F
# elg
# phones ['EH', 'L', 'G'] ['G', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 'g' in 'ag'] ['e' in 'eb', 'l' in 'al', 'g' in 'ag']
# yay!
# elg ['e' in 'eb', 'l' in 'al', 'g' in 'ag'] 3
# ['e' in 'eb', 'l' in 'al', 'g' in 'ag'] 3
# ['EH', 'L', 'G']
# elg EH L G
# eli
# phones ['IY', 'L', 'AY'] ['AY', 'L', 'IY']
# front & back ['e' in 'be', 'l' in 'al', 'i' in 'fi'] ['e' in 'be', 'l' in 'al', 'i' in 'fi']
# yay!
# eli ['e' in 'be', 'l' in 'al', 'i' in 'fi'] 3
# ['e' in 'be', 'l' in 'al', 'i' in 'fi'] 3
# ['IY', 'L', 'AY']
# eli IY L AY
# elk
# phones ['EH', 'L', 'K'] ['K', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 'k' in 'ka'] ['e' in 'eb', 'l' in 'al', 'k' in 'ka']
# yay!
# elk ['e' in 'eb', 'l' in 'al', 'k' in 'ka'] 3
# ['e' in 'eb', 'l' in 'al', 'k' in 'ka'] 3
# ['EH', 'L', 'K']
# elk EH L K
# ell
# phones ['EH', 'L'] ['L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al'] ['l' in 'al']
# missing grapheme
# too long
# missing phoneme (overlap) L
# 'l' in 'ell'
# ell EH L
# elm
# phones ['EH', 'L', 'M'] ['M', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 'm' in 'am'] ['e' in 'eb', 'l' in 'al', 'm' in 'am']
# yay!
# elm ['e' in 'eb', 'l' in 'al', 'm' in 'am'] 3
# ['e' in 'eb', 'l' in 'al', 'm' in 'am'] 3
# ['EH', 'L', 'M']
# elm EH L M
# els
# phones ['EH', 'L', 'Z'] ['Z', 'L', 'EH']
# front & back ['e' in 'eb', 'l' in 'al', 's' in 'as'] ['e' in 'eb', 'l' in 'al', 's' in 'as']
# yay!
# els ['e' in 'eb', 'l' in 'al', 's' in 'as'] 3
# ['e' in 'eb', 'l' in 'al', 's' in 'as'] 3
# ['EH', 'L', 'Z']
# els EH L Z
# ely
# phones ['IY', 'L', 'AY'] ['AY', 'L', 'IY']
# front & back ['e' in 'be', 'l' in 'al', 'y' in 'by'] ['e' in 'be', 'l' in 'al', 'y' in 'by']
# yay!
# ely ['e' in 'be', 'l' in 'al', 'y' in 'by'] 3
# ['e' in 'be', 'l' in 'al', 'y' in 'by'] 3
# ['IY', 'L', 'AY']
# ely IY L AY
# ema
# phones ['IY', 'M', 'AH'] ['AH', 'M', 'IY']
# front & back ['e' in 'be', 'm' in 'am', 'a' in 'an'] ['e' in 'be', 'm' in 'am', 'a' in 'an']
# yay!
# ema ['e' in 'be', 'm' in 'am', 'a' in 'an'] 3
# ['e' in 'be', 'm' in 'am', 'a' in 'an'] 3
# ['IY', 'M', 'AH']
# ema IY M AH
# emo
# phones ['IY', 'M', 'OW'] ['OW', 'M', 'IY']
# front & back ['e' in 'be', 'm' in 'am', 'o' in 'bo'] ['e' in 'be', 'm' in 'am', 'o' in 'bo']
# yay!
# emo ['e' in 'be', 'm' in 'am', 'o' in 'bo'] 3
# ['e' in 'be', 'm' in 'am', 'o' in 'bo'] 3
# ['IY', 'M', 'OW']
# emo IY M OW
# emu
# too long! emu ['IY', 'M', 'Y', 'UW']
# emu IY M Y UW
# ena
# phones ['EH', 'N', 'AH'] ['AH', 'N', 'EH']
# front & back ['e' in 'eb', 'n' in 'an', 'a' in 'an'] ['e' in 'eb', 'n' in 'an', 'a' in 'an']
# yay!
# ena ['e' in 'eb', 'n' in 'an', 'a' in 'an'] 3
# ['e' in 'eb', 'n' in 'an', 'a' in 'an'] 3
# ['EH', 'N', 'AH']
# ena EH N AH
# end
# phones ['EH', 'N', 'D'] ['D', 'N', 'EH']
# front & back ['e' in 'eb', 'n' in 'an', 'd' in 'da'] ['e' in 'eb', 'n' in 'an', 'd' in 'da']
# yay!
# end ['e' in 'eb', 'n' in 'an', 'd' in 'da'] 3
# ['e' in 'eb', 'n' in 'an', 'd' in 'da'] 3
# ['EH', 'N', 'D']
# end EH N D
# eng
# phones ['EH', 'NG'] ['NG', 'EH']
# front & back ['e' in 'eb', 'ng' in 'ang'] ['e' in 'eb', 'ng' in 'ang']
# yay!
# eng ['e' in 'eb', 'ng' in 'ang'] 2
# ['e' in 'eb', 'ng' in 'ang'] 2
# ['EH', 'NG']
# eng EH NG
# eno
# phones ['EH', 'N', 'OW'] ['OW', 'N', 'EH']
# front & back ['e' in 'eb', 'n' in 'an', 'o' in 'bo'] ['e' in 'eb', 'n' in 'an', 'o' in 'bo']
# yay!
# eno ['e' in 'eb', 'n' in 'an', 'o' in 'bo'] 3
# ['e' in 'eb', 'n' in 'an', 'o' in 'bo'] 3
# ['EH', 'N', 'OW']
# eno EH N OW
# ent
# phones ['EH', 'N', 'T'] ['T', 'N', 'EH']
# front & back ['e' in 'eb', 'n' in 'an', 't' in 'at'] ['e' in 'eb', 'n' in 'an', 't' in 'at']
# yay!
# ent ['e' in 'eb', 'n' in 'an', 't' in 'at'] 3
# ['e' in 'eb', 'n' in 'an', 't' in 'at'] 3
# ['EH', 'N', 'T']
# ent EH N T
# enz
# phones ['EH', 'N', 'Z'] ['Z', 'N', 'EH']
# front & back ['e' in 'eb', 'n' in 'an', 'z' in 'oz'] ['e' in 'eb', 'n' in 'an', 'z' in 'oz']
# yay!
# enz ['e' in 'eb', 'n' in 'an', 'z' in 'oz'] 3
# ['e' in 'eb', 'n' in 'an', 'z' in 'oz'] 3
# ['EH', 'N', 'Z']
# enz EH N Z
# eon
# phones ['IY', 'AA', 'N'] ['N', 'AA', 'IY']
# front & back ['e' in 'be', 'o' in 'og', 'n' in 'an'] ['e' in 'be', 'o' in 'og', 'n' in 'an']
# yay!
# eon ['e' in 'be', 'o' in 'og', 'n' in 'an'] 3
# ['e' in 'be', 'o' in 'og', 'n' in 'an'] 3
# ['IY', 'AA', 'N']
# eon IY AA N
# eos
# phones ['IY', 'AO', 'S'] ['S', 'AO', 'IY']
# front & back ['e' in 'be', 'o' in 'om', 's' in 'es'] ['e' in 'be', 'o' in 'om', 's' in 'es']
# yay!
# eos ['e' in 'be', 'o' in 'om', 's' in 'es'] 3
# ['e' in 'be', 'o' in 'om', 's' in 'es'] 3
# ['IY', 'AO', 'S']
# eos IY AO S
# epa
# too long! epa ['IY', 'P', 'IY', 'EY']
# epa IY P IY EY
# epp
# phones ['EH', 'P'] ['P', 'EH']
# front & back ['e' in 'eb', 'p' in 'pa'] ['p' in 'pa']
# missing grapheme
# too long
# missing phoneme (overlap) P
# 'p' in 'epp'
# epp EH P
# era
# phones ['EH', 'R', 'AH'] ['AH', 'R', 'EH']
# front & back ['e' in 'eb', 'r' in 're', 'a' in 'an'] ['e' in 'eb', 'r' in 're', 'a' in 'an']
# yay!
# era ['e' in 'eb', 'r' in 're', 'a' in 'an'] 3
# ['e' in 'eb', 'r' in 're', 'a' in 'an'] 3
# ['EH', 'R', 'AH']
# era EH R AH
# era
# phones ['IH', 'R', 'AH'] ['AH', 'R', 'IH']
# front & back [] ['r' in 're', 'a' in 'an']
# missing grapheme e
# missing phoneme (clean) IH
# era IH R AH
# erb
# phones ['ER', 'B'] ['B', 'ER']
# front & back ['er' in 'er', 'b' in 'ab'] ['er' in 'er', 'b' in 'ab']
# yay!
# erb ['er' in 'er', 'b' in 'ab'] 2
# ['er' in 'er', 'b' in 'ab'] 2
# ['ER', 'B']
# erb ER B
# ere
# phones ['EH', 'R'] ['R', 'EH']
# front & back ['e' in 'eb', 'r' in 're'] ['e' in 'eb', 're' in 'are']
# missing grapheme e
# too long
# missing phoneme (overlap) R
# 're' in 'ere'
# ere EH R
# erk
# phones ['ER', 'K'] ['K', 'ER']
# front & back ['er' in 'er', 'k' in 'ka'] ['er' in 'er', 'k' in 'ka']
# yay!
# erk ['er' in 'er', 'k' in 'ka'] 2
# ['er' in 'er', 'k' in 'ka'] 2
# ['ER', 'K']
# erk ER K
# erl
# phones ['ER', 'L'] ['L', 'ER']
# front & back ['er' in 'er', 'l' in 'al'] ['er' in 'er', 'l' in 'al']
# yay!
# erl ['er' in 'er', 'l' in 'al'] 2
# ['er' in 'er', 'l' in 'al'] 2
# ['ER', 'L']
# erl ER L
# ero
# phones ['IH', 'R', 'OW'] ['OW', 'R', 'IH']
# front & back ['e' in 'era', 'r' in 're', 'o' in 'bo'] ['e' in 'era', 'r' in 're', 'o' in 'bo']
# yay!
# ero ['e' in 'era', 'r' in 're', 'o' in 'bo'] 3
# ['e' in 'era', 'r' in 're', 'o' in 'bo'] 3
# ['IH', 'R', 'OW']
# ero IH R OW
# err
# phones ['EH', 'R'] ['R', 'EH']
# front & back ['e' in 'eb', 'r' in 're'] ['r' in 're']
# missing grapheme
# too long
# missing phoneme (overlap) R
# 'r' in 'err'
# err EH R
# err
# phones ['ER'] ['ER']
# front & back ['er' in 'er'] ['r' in 'amr']
# missing grapheme
# too long
# missing phoneme (overlap) ER
# 'er' in 'err'
# err ER
# ers
# phones ['ER', 'Z'] ['Z', 'ER']
# front & back ['er' in 'er', 's' in 'as'] ['er' in 'er', 's' in 'as']
# yay!
# ers ['er' in 'er', 's' in 'as'] 2
# ['er' in 'er', 's' in 'as'] 2
# ['ER', 'Z']
# ers ER Z
# ers
# too long! ers ['IY', 'AA', 'R', 'EH', 'S']
# ers IY AA R EH S
# esh
# phones ['EH', 'SH'] ['SH', 'EH']
# front & back ['e' in 'eb', 'sh' in 'ash'] ['e' in 'eb', 'sh' in 'ash']
# yay!
# esh ['e' in 'eb', 'sh' in 'ash'] 2
# ['e' in 'eb', 'sh' in 'ash'] 2
# ['EH', 'SH']
# esh EH SH
# ess
# phones ['EH', 'S'] ['S', 'EH']
# front & back ['e' in 'eb', 's' in 'es'] ['s' in 'es']
# missing grapheme
# too long
# missing phoneme (overlap) S
# 's' in 'ess'
# ess EH S
# est
# phones ['EH', 'S', 'T'] ['T', 'S', 'EH']
# front & back ['e' in 'eb', 's' in 'es', 't' in 'at'] ['e' in 'eb', 's' in 'es', 't' in 'at']
# yay!
# est ['e' in 'eb', 's' in 'es', 't' in 'at'] 3
# ['e' in 'eb', 's' in 'es', 't' in 'at'] 3
# ['EH', 'S', 'T']
# est EH S T
# etc
# too long! etc ['EH', 'T', 'S', 'EH', 'T', 'ER', 'AH']
# etc EH T S EH T ER AH
# eva
# phones ['EY', 'V', 'AH'] ['AH', 'V', 'EY']
# front & back ['e' in 'de', 'v' in 'vi', 'a' in 'an'] ['e' in 'de', 'v' in 'vi', 'a' in 'an']
# yay!
# eva ['e' in 'de', 'v' in 'vi', 'a' in 'an'] 3
# ['e' in 'de', 'v' in 'vi', 'a' in 'an'] 3
# ['EY', 'V', 'AH']
# eva EY V AH
# eva
# phones ['IY', 'V', 'AH'] ['AH', 'V', 'IY']
# front & back ['e' in 'be', 'v' in 'vi', 'a' in 'an'] ['e' in 'be', 'v' in 'vi', 'a' in 'an']
# yay!
# eva ['e' in 'be', 'v' in 'vi', 'a' in 'an'] 3
# ['e' in 'be', 'v' in 'vi', 'a' in 'an'] 3
# ['IY', 'V', 'AH']
# eva IY V AH
# eve
# phones ['IY', 'V'] ['V', 'IY']
# front & back ['e' in 'be', 'v' in 'vi'] []
# missing grapheme e
# missing phoneme (overlap) V
# 've' in 'eve'
# eve IY V
# ewe
# phones ['Y', 'UW'] ['UW', 'Y']
# front & back [] []
# missing grapheme ewe
# missing phoneme (clean) Y
# ewe Y UW
# ewy
# phones ['Y', 'UW', 'IY'] ['IY', 'UW', 'Y']
# front & back [] ['ew' in 'dew', 'y' in 'uy']
# missing grapheme
# missing phoneme (clean) Y
# ewy Y UW IY
# ex
# phones ['EH', 'K', 'S'] ['S', 'K', 'EH']
# front & back ['e' in 'eb', 'k' in 'ka', 's' in 'es'] ['e' in 'eb', 'k' in 'ka', 's' in 'es']
# yay!
# ex ['e' in 'eb', 'k' in 'ka', 's' in 'es'] 3
# ['e' in 'eb', 'k' in 'ka', 's' in 'es'] 3
# ['EH', 'K', 'S']
# ex EH K S
# eye
# phones ['AY'] ['AY']
# front & back [] ['ye' in 'bye']
# missing grapheme e
# missing phoneme (overlap) AY
# 'eye' in 'eye'
# eye AY
# bad characters f'd
# f'd EH F D
# bad characters f's
# f's EH F S
# fab
# phones ['F', 'AE', 'B'] ['B', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'b' in 'ab'] ['f' in 'fe', 'a' in 'ad', 'b' in 'ab']
# yay!
# fab ['f' in 'fe', 'a' in 'ad', 'b' in 'ab'] 3
# ['f' in 'fe', 'a' in 'ad', 'b' in 'ab'] 3
# ['F', 'AE', 'B']
# fab F AE B
# fac
# phones ['F', 'AE', 'K'] ['K', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'c' in 'ca'] ['f' in 'fe', 'a' in 'ad', 'c' in 'ca']
# yay!
# fac ['f' in 'fe', 'a' in 'ad', 'c' in 'ca'] 3
# ['f' in 'fe', 'a' in 'ad', 'c' in 'ca'] 3
# ['F', 'AE', 'K']
# fac F AE K
# fad
# phones ['F', 'AE', 'D'] ['D', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'd' in 'da'] ['f' in 'fe', 'a' in 'ad', 'd' in 'da']
# yay!
# fad ['f' in 'fe', 'a' in 'ad', 'd' in 'da'] 3
# ['f' in 'fe', 'a' in 'ad', 'd' in 'da'] 3
# ['F', 'AE', 'D']
# fad F AE D
# fae
# phones ['F', 'AY'] ['AY', 'F']
# front & back ['f' in 'fe', 'ae' in 'bae'] ['f' in 'fe', 'ae' in 'bae']
# yay!
# fae ['f' in 'fe', 'ae' in 'bae'] 2
# ['f' in 'fe', 'ae' in 'bae'] 2
# ['F', 'AY']
# fae F AY
# fag
# phones ['F', 'AE', 'G'] ['G', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'g' in 'ag'] ['f' in 'fe', 'a' in 'ad', 'g' in 'ag']
# yay!
# fag ['f' in 'fe', 'a' in 'ad', 'g' in 'ag'] 3
# ['f' in 'fe', 'a' in 'ad', 'g' in 'ag'] 3
# ['F', 'AE', 'G']
# fag F AE G
# fan
# phones ['F', 'AE', 'N'] ['N', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'n' in 'an'] ['f' in 'fe', 'a' in 'ad', 'n' in 'an']
# yay!
# fan ['f' in 'fe', 'a' in 'ad', 'n' in 'an'] 3
# ['f' in 'fe', 'a' in 'ad', 'n' in 'an'] 3
# ['F', 'AE', 'N']
# fan F AE N
# fao
# phones ['F', 'AW'] ['AW', 'F']
# front & back ['f' in 'fe', 'ao' in 'aoi'] ['f' in 'fe', 'ao' in 'aoi']
# yay!
# fao ['f' in 'fe', 'ao' in 'aoi'] 2
# ['f' in 'fe', 'ao' in 'aoi'] 2
# ['F', 'AW']
# fao F AW
# far
# phones ['F', 'AA', 'R'] ['R', 'AA', 'F']
# front & back ['f' in 'fe', 'a' in 'ar', 'r' in 're'] ['f' in 'fe', 'a' in 'ar', 'r' in 're']
# yay!
# far ['f' in 'fe', 'a' in 'ar', 'r' in 're'] 3
# ['f' in 'fe', 'a' in 'ar', 'r' in 're'] 3
# ['F', 'AA', 'R']
# far F AA R
# fat
# phones ['F', 'AE', 'T'] ['T', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 't' in 'at'] ['f' in 'fe', 'a' in 'ad', 't' in 'at']
# yay!
# fat ['f' in 'fe', 'a' in 'ad', 't' in 'at'] 3
# ['f' in 'fe', 'a' in 'ad', 't' in 'at'] 3
# ['F', 'AE', 'T']
# fat F AE T
# faux
# phones ['F', 'OW'] ['OW', 'F']
# front & back ['f' in 'fe', 'au' in 'au'] ['f' in 'fe', 'au' in 'au']
# yay!
# faux ['f' in 'fe', 'au' in 'au'] 2
# ['f' in 'fe', 'au' in 'au'] 2
# ['F', 'OW']
# faux F OW
# faw
# phones ['F', 'AO'] ['AO', 'F']
# front & back ['f' in 'fe', 'aw' in 'aw'] ['f' in 'fe', 'aw' in 'aw']
# yay!
# faw ['f' in 'fe', 'aw' in 'aw'] 2
# ['f' in 'fe', 'aw' in 'aw'] 2
# ['F', 'AO']
# faw F AO
# fay
# phones ['F', 'EY'] ['EY', 'F']
# front & back ['f' in 'fe', 'ay' in 'ay'] ['f' in 'fe', 'ay' in 'ay']
# yay!
# fay ['f' in 'fe', 'ay' in 'ay'] 2
# ['f' in 'fe', 'ay' in 'ay'] 2
# ['F', 'EY']
# fay F EY
# faz
# phones ['F', 'AE', 'Z'] ['Z', 'AE', 'F']
# front & back ['f' in 'fe', 'a' in 'ad', 'z' in 'oz'] ['f' in 'fe', 'a' in 'ad', 'z' in 'oz']
# yay!
# faz ['f' in 'fe', 'a' in 'ad', 'z' in 'oz'] 3
# ['f' in 'fe', 'a' in 'ad', 'z' in 'oz'] 3
# ['F', 'AE', 'Z']
# faz F AE Z
# fbi
# too long! fbi ['EH', 'F', 'B', 'IY', 'AY']
# fbi EH F B IY AY
# fda
# too long! fda ['EH', 'F', 'D', 'IY', 'EY']
# fda EH F D IY EY
# fed
# phones ['F', 'EH', 'D'] ['D', 'EH', 'F']
# front & back ['f' in 'fe', 'e' in 'eb', 'd' in 'da'] ['f' in 'fe', 'e' in 'eb', 'd' in 'da']
# yay!
# fed ['f' in 'fe', 'e' in 'eb', 'd' in 'da'] 3
# ['f' in 'fe', 'e' in 'eb', 'd' in 'da'] 3
# ['F', 'EH', 'D']
# fed F EH D
# fee
# phones ['F', 'IY'] ['IY', 'F']
# front & back ['f' in 'fe', 'e' in 'be'] ['e' in 'be']
# missing grapheme
# too long
# missing phoneme (overlap) IY
# 'e' in 'fee'
# fee F IY
# fel
# phones ['F', 'EH', 'L'] ['L', 'EH', 'F']
# front & back ['f' in 'fe', 'e' in 'eb', 'l' in 'al'] ['f' in 'fe', 'e' in 'eb', 'l' in 'al']
# yay!
# fel ['f' in 'fe', 'e' in 'eb', 'l' in 'al'] 3
# ['f' in 'fe', 'e' in 'eb', 'l' in 'al'] 3
# ['F', 'EH', 'L']
# fel F EH L
# fen
# phones ['F', 'EH', 'N'] ['N', 'EH', 'F']
# front & back ['f' in 'fe', 'e' in 'eb', 'n' in 'an'] ['f' in 'fe', 'e' in 'eb', 'n' in 'an']
# yay!
# fen ['f' in 'fe', 'e' in 'eb', 'n' in 'an'] 3
# ['f' in 'fe', 'e' in 'eb', 'n' in 'an'] 3
# ['F', 'EH', 'N']
# fen F EH N
# fer
# phones ['F', 'ER'] ['ER', 'F']
# front & back ['f' in 'fe', 'er' in 'er'] ['f' in 'fe', 'er' in 'er']
# yay!
# fer ['f' in 'fe', 'er' in 'er'] 2
# ['f' in 'fe', 'er' in 'er'] 2
# ['F', 'ER']
# fer F ER
# fer
# phones ['F', 'EH', 'R'] ['R', 'EH', 'F']
# front & back ['f' in 'fe', 'e' in 'eb', 'r' in 're'] ['f' in 'fe', 'e' in 'eb', 'r' in 're']
# yay!
# fer ['f' in 'fe', 'e' in 'eb', 'r' in 're'] 3
# ['f' in 'fe', 'e' in 'eb', 'r' in 're'] 3
# ['F', 'EH', 'R']
# fer F EH R
# few
# phones ['F', 'Y', 'UW'] ['UW', 'Y', 'F']
# front & back ['f' in 'fe', '' in 'ewy', 'ew' in 'dew'] ['f' in 'fe', '' in 'ewy', 'ew' in 'dew']
# yay!
# few ['f' in 'fe', 'ew' in 'dew'] 2
# ['f' in 'fe', 'ew' in 'dew'] 2
# ['F', 'Y', 'UW']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 test2 = learn3(test1, threeLetter, exLen=3, debug=True)
#
# Cell In[61], line 120, in learn3(spellings, words, exLen, debug)
#     118 newSpells = {s: copy(spellings[s]) for s in spellings}
#     119 for word in words:
# --> 120     spell3(word, newSpells, exLen=exLen, debug=debug)
#     121     if debug:
#     122         print(word, word.p)
#
# Cell In[61], line 68, in spell3(word, spellings, exLen, debug)
#      66 g = frontSpell[phones.index(exPhone)]
#      67 p = spellings[exPhone]
# ---> 68 exGraph = p[p.index(g)]
#      69 if len(word.s) == exLen and not exGraph.set:
#      70     exGraph.setExample(word)
#
# ValueError: 'ew' in 'dew' is not in list

# %% [markdown]
# Brainstorming potential solutions:
#
# For issue one:
# <ul>
#     <li>completely ignore words which my program thinks is made of a single grapheme</li>
#     <li>do a first pass, where those words are ignored. then allow monographic words. this assumes that a later word will contain the correct spellings to fix it</li>
# </ul>
# I like the second idea, but I'm not sure if it would actually work. I suppose I could just check whether the word actually contains only one phoneme, and only allow it in that case
#
# Issue two:
# <ul>
#     <li>Figure out a way to incorporate silent letters into my program's understanding</li>
#     <li>When my program thinks it's spelled a word correctly, check if it accounts for every phoneme. If it doesn't, force it to move on</li>
# </ul>
#
# I feel like the first idea goes against what I'm trying to do here. There's no consistent way to determine which letters are silent and which aren't, and my program assumes exactly one grapheme (excepting x) for every phoneme. As for the second idea, I don't know what it'll do if it 'moves on' and then fails to spell it. I need to work that out
#
# Issue three: solve issue two
#
# Important note: I don't know which letters of the word 'ewe' make which sounds. My opinion is that the first 'e' is the /J/ sound, and the remaining 'we' represents the ending /EW/. But I don't see one correct answer. And that means I don't have an objective way to measure my program's success. That sounds like a problem, but maybe it's cool that I, in a way, made something with its own ability to interpret language and develop its own opinions.

# %%
## from time import sleep
from copy import copy

def sideSpell4(word, phones, spells, polarity):
    currentSpell = []
    for p in phones:
        oldLen = len(currentSpell)
        for s in spells[p]:
            newSpell = copy(currentSpell)
            if not polarity:
                newSpell.append(s.g)
                if word.s.startswith(''.join([a if not isinstance(a, graphExample) else a.g for a in newSpell])):
                    currentSpell.append(s)
                    break
            else:
                newSpell.insert(0, s.g)
                if word.s.endswith(''.join([a if not isinstance(a, graphExample) else a.g for a in newSpell])):
                    currentSpell.insert(0, s)
                    break                
        if len(currentSpell) == oldLen:
            break
    return currentSpell

def spell4(word, spellings, exLen=4, debug=False):
    word.s = word.s.lower()
    if not word.s.isalnum():
        if debug:
            print("bad characters", word.s)
        return False
    if debug:
        print(word)
    phones = word.p.split()
    if len(word.s) < len(phones):
        if debug:
            print("too long!", word.s, phones)
        return False
    if not set(word.s) & set('aeiouy'):
        if debug:
            print("no vowels -> not a word!", word.s, phones)
        return False
    if word.s[:-2] == 'le' and phones[:-2] == ['AH', 'L'] and word.s[-3] not in ['aeiou']:
        phones.append(phones.pop[-2])
        if debug:
            print("special case: L")
    rphones = copy(phones)
    rphones.reverse()
    if debug:
        print("phones", phones, rphones)
    frontSpell = sideSpell4(word, phones, spellings, 0)
    frontStr = [a.g for a in frontSpell]
    backSpell = sideSpell4(word, rphones, spellings, 1)
    backStr = [a.g for a in backSpell]
    if debug:
        print("front & back", frontSpell, backSpell)
    if '' in frontSpell:
        frontSpell.remove('')
    if '' in backSpell:
        backSpell.remove('')
    if len(phones) > (len(frontSpell) + len(backSpell) + 1):
        if debug:
            print("failure to spell")
        return False
    if frontSpell == backSpell and ''.join(frontStr) == word.s:
        if debug:
            print('yay!')
            print(word, frontSpell, len(frontSpell))
            print(backSpell, len(backSpell))
            print(phones)
        exPhone = choice(phones)
        g = frontSpell[phones.index(exPhone)]
        p = spellings[exPhone]
        exGraph = p[p.index(g)]
        if len(word.s) == exLen and not exGraph.set:
            exGraph.setExample(word)
        return True
    missingG = graphExample(word.s.removeprefix(''.join(frontStr)).removesuffix(''.join(backStr)), isX=word.x)
    #if not missingG.g:
    #    missingG = backSpell[0]
    if debug:
        print("missing grapheme", missingG)
    if len(frontSpell + backSpell) > len(phones):
            #print(word, frontSpell, len(frontSpell))
            #print(backSpell, len(backSpell))
            #print(phones)
            if debug:
                print("too long")
            del backSpell[0]
    if len(frontSpell + backSpell) < len(phones):
        try:
            missingP = phones[len(frontSpell)]
            if debug:
                print("missing phoneme (clean)", missingP)
            if len(word.s) == exLen and not missingG.set:
                missingG.setExample(word)        
            spellings[missingP].append(missingG)    
        except IndexError as e:
            if debug:
                print(word, frontSpell, len(frontSpell))
                print(backSpell, len(backSpell))
                print(phones)
            raise e
    else:
        missingP = phones[len(frontSpell) - 1]
        if debug:
            print("missing phoneme (overlap)", missingP)
        try:
            newG = graphExample(''.join((frontStr[-1], missingG.g) if frontStr else (missingG.g, backStr[0])), isX = missingG.g.count('x') or (frontStr[-1].count('x') if frontStr else backStr[0].count('x')))
            if len(word.s) == exLen and not newG.set:
                newG.setExample(word)  
            spellings[missingP].append(newG)
            if debug:
                print(newG)
        except IndexError as e:
            if debug:
                print(word, frontSpell, len(frontSpell))
                print(backSpell, len(backSpell))
                print(phones)
                print(missingP)
            raise e

def learn3(spellings, words, exLen=4, debug=False):
    newSpells = {s: copy(spellings[s]) for s in spellings}
    for word in words:
        spell3(word, newSpells, exLen=exLen, debug=debug)
        if debug:
            print(word, word.p)
        #break
    return newSpells
